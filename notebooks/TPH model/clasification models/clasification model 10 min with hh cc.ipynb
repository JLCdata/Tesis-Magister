# %% [markdown]
# # model TPH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
import re
from dateutil.parser import parse
import string
import warnings
warnings.filterwarnings('ignore')
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_percentage_error
import missingno as msno
from plotly.subplots import make_subplots
from sklearn.preprocessing import MinMaxScaler
import scipy
import researchpy as rp
from matplotlib.offsetbox import AnchoredText
import pacmap
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
import plotly.express as px
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split 
# Import Halving Grid Search
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.metrics import confusion_matrix
import xgboost as xgb
from scipy.stats import kurtosis,skew
from numpy import mean,sqrt,square
from scipy.fftpack import fft, fftfreq
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import PredefinedSplit
sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 100

# %%
# Función que filtra tags por alta correlación
def corrkill(dataframe, features, corr_cut=0.8):

    df = dataframe[features]
    dfcorr = pd.DataFrame(np.triu(df.corr()), columns=df.columns, index=df.columns)
    dfcorr = dfcorr.stack().reset_index()
    dfcorr.columns = ['Feat1','Feat2','Val']
    dfcorr = dfcorr[~dfcorr['Val'].isin([0,1])]
    dfcorr = dfcorr[dfcorr['Val'].abs()>corr_cut]
    dfcorr["Val"]=dfcorr["Val"].abs()
    
    return list(dfcorr['Feat2']), dfcorr.sort_values(by="Val",ascending=False)

# %%
variables_interes=['pyrite law', 'chalcopyrite law',
       'chalcocite law', 'covelin law', 'crusher index', 'sag power index',
       'ball work index', 'bornite law','charge cell', 'TPH','water', 'speed','HH TPH', 'granulometry', 'Edad','loss of TPH',"power","solid percentage","HH charge cell","LL charge cell"]
variables_interes
# Out:
# ['pyrite law',
#  'chalcopyrite law',
#  'chalcocite law',
#  'covelin law',
#  'crusher index',
#  'sag power index',
#  'ball work index',
#  'bornite law',
#  'charge cell',
#  'TPH',
#  'water',
#  'speed',
#  'HH TPH',
#  'granulometry',
#  'Edad',
#  'loss of TPH',
#  'power',
#  'solid percentage',
#  'HH charge cell',
#  'LL charge cell']

# %%
# read df full csv
df_full=pd.read_csv('../../data/consolidated data/df_full_01November2022.csv', parse_dates=['Timestamp'], index_col='Timestamp')[variables_interes]#["2020":"2021"]
df_full

# %% [markdown]
# ***Custom features***

# %%
df_full["delta HH charge cell"]=df_full["HH charge cell"]-df_full["charge cell"]

# %%
df_full["delta LL charge cell"]=df_full["charge cell"]-df_full["LL charge cell"]

# %%
df_corr = df_full.dropna().corr()
corr_tph=pd.DataFrame(df_corr.abs().TPH.sort_values(ascending=False))
top_corr=corr_tph[corr_tph.TPH>=0]
top_corr

# %% [markdown]
# # Feature Engineering

# %%
def feature_engineering(df):
      
    targets = ["TPH","Edad","loss of TPH","HH TPH"]
    df_vars = df.copy()
    column_inicial=df_vars.columns

    for column in df_vars:
    
        if (column not in targets):

            ## 10 min
            #df_vars[f"skew_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:skew(x))
            #df_vars[f"kurt_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:kurtosis(x))
            df_vars[f"mean_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:np.nanmean(list(x)))
            df_vars[f"max_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:np.nanmax(list(x)))
            #df_vars[f"sum_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:np.nansum(list(x)))
            df_vars[f"min_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x:np.nanmin(list(x)))
            df_vars[f"rms_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x: sqrt(mean(square(list(x)))))
            df_vars[f"var_{column}_10"]=df_vars[column].rolling(window=10).apply(lambda x: np.nanvar(x))

            # 5 min
            df_vars[f"mean_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x:np.nanmean(list(x)))
            df_vars[f"max_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x:np.nanmax(list(x)))
            #df_vars[f"sum_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x:np.nansum(list(x)))
            df_vars[f"min_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x:np.nanmin(list(x)))
            df_vars[f"rms_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x: sqrt(mean(square(list(x)))))
            df_vars[f"var_{column}_5"]=df_vars[column].rolling(window=5).apply(lambda x: np.nanvar(x))

            # 3 min
            #df_vars[f"skew_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:skew(x))
            #df_vars[f"kurt_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:kurtosis(x))
            df_vars[f"mean_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:np.nanmean(list(x)))
            df_vars[f"max_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:np.nanmax(list(x)))
            #df_vars[f"sum_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:np.nansum(list(x)))
            df_vars[f"min_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x:np.nanmin(list(x)))
            df_vars[f"rms_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x: sqrt(mean(square(list(x)))))
            df_vars[f"var_{column}_3"]=df_vars[column].rolling(window=3).apply(lambda x: np.nanvar(x))

            # Fourier
            #L=10
            #df_vars[f"fourier_{L}_max_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmax(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_min_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmin(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_mean_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmean(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_sum_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nansum(abs(fft(list(x))[1:int(L/2)]/(L/2))))
#
            #L=5
            #df_vars[f"fourier_{L}_max_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmax(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_min_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmin(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_mean_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nanmean(abs(fft(list(x))[1:int(L/2)]/(L/2))))
            #df_vars[f"fourier_{L}_sum_{column}"]=df_vars[column].rolling(window=L).apply(lambda x:    np.nansum(abs(fft(list(x))[1:int(L/2)]/(L/2))))


    for column in column_inicial:
        if (column not in targets):
            # lags  
            df_vars[f"{column}_(t-1)"] = df_vars[column].shift(1)
            df_vars[f'{column}_(t-2)'] = df_vars[column].shift(2)
            df_vars[f'{column}_(t-3)'] = df_vars[column].shift(3)
            df_vars[f'{column}_(t-4)'] = df_vars[column].shift(4)
            df_vars[f'{column}_(t-5)'] = df_vars[column].shift(5)
           
    
    return df_vars

# %%
df_full.head()

# %%
df_features=feature_engineering(df_full)

# %%
# Se guarda en csv
df_features.to_csv('../../data/consolidated data/df_features_'+pd.to_datetime('today').strftime('%d%B%Y')+'.csv', index=True)

# %%
df_features.shape

# %%
# read df full csv
df_features=pd.read_csv('../../data/consolidated data/df_features_25November2022.csv', parse_dates=['Timestamp'], index_col='Timestamp')#["2020":"2021"]
df_features["TPH"]=df_features["TPH"].shift(-10)
df_features["loss of TPH"]=df_features["loss of TPH"].shift(-10)
df_features.dropna(inplace=True)
df_features.sort_index(inplace=True)
df_features.shape
# Out:
# (856091, 382)

# %%
# Verificando si hay duplicados
u=[i for i in df_features.columns if (not re.match(".*water",i)) and (not re.match(".*power",i)) ]
y=[i for i in df_features.columns if  re.match(".*sag power index",i)] 
u=y+u
df_features=df_features[u]
df_features.head(1)
# Out:
#                      sag power index  mean_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00          98.5569                  98.5569
#
#                      max_sag power index_10  min_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569                 98.5569
#
#                      rms_sag power index_10  var_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569            2.019484e-28
#
#                      mean_sag power index_5  max_sag power index_5  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569                98.5569
#
#                      min_sag power index_5  rms_sag power index_5  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      var_sag power index_5  mean_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                    0.0                 98.5569
#
#                      max_sag power index_3  min_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      rms_sag power index_3  var_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                    0.0
#
#                      sag power index_(t-1)  sag power index_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      sag power index_(t-3)  sag power index_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      sag power index_(t-5)  pyrite law  chalcopyrite law  \
# Timestamp
# 2020-01-10 04:14:00                98.5569         2.3              1.76
#
#                      chalcocite law  covelin law  crusher index  \
# Timestamp
# 2020-01-10 04:14:00             0.5         0.02        19.7649
#
#                      ball work index  bornite law  charge cell          TPH  \
# Timestamp
# 2020-01-10 04:14:00          15.4504         0.05   790.204768  3965.015072
#
#                         speed  HH TPH  granulometry  Edad  loss of TPH  \
# Timestamp
# 2020-01-10 04:14:00  8.999591  3950.0     49.124744   1.0          0.0
#
#                      solid percentage  HH charge cell  LL charge cell  \
# Timestamp
# 2020-01-10 04:14:00         74.485469           850.0           770.0
#
#                      delta HH charge cell  delta LL charge cell  \
# Timestamp
# 2020-01-10 04:14:00             59.795232             20.204768
#
#                      mean_pyrite law_10  max_pyrite law_10  min_pyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                 2.3                2.3                2.3
#
#                      rms_pyrite law_10  var_pyrite law_10  mean_pyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                2.3                0.0                2.3
#
#                      max_pyrite law_5  min_pyrite law_5  rms_pyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               2.3
#
#                      var_pyrite law_5  mean_pyrite law_3  max_pyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.0                2.3               2.3
#
#                      min_pyrite law_3  rms_pyrite law_3  var_pyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               0.0
#
#                      mean_chalcopyrite law_10  max_chalcopyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                      1.76                     1.76
#
#                      min_chalcopyrite law_10  rms_chalcopyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                     1.76                     1.76
#
#                      var_chalcopyrite law_10  mean_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00             4.930381e-32                     1.76
#
#                      max_chalcopyrite law_5  min_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      rms_chalcopyrite law_5  var_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    1.76            4.930381e-32
#
#                      mean_chalcopyrite law_3  max_chalcopyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00                     1.76                    1.76
#
#                      min_chalcopyrite law_3  rms_chalcopyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      var_chalcopyrite law_3  mean_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                     0.0                     0.5
#
#                      max_chalcocite law_10  min_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                    0.5
#
#                      rms_chalcocite law_10  var_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                    0.0
#
#                      mean_chalcocite law_5  max_chalcocite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                   0.5
#
#                      min_chalcocite law_5  rms_chalcocite law_5  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      var_chalcocite law_5  mean_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                    0.5
#
#                      max_chalcocite law_3  min_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      rms_chalcocite law_3  var_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.0
#
#                      mean_covelin law_10  max_covelin law_10  \
# Timestamp
# 2020-01-10 04:14:00                 0.02                0.02
#
#                      min_covelin law_10  rms_covelin law_10  \
# Timestamp
# 2020-01-10 04:14:00                0.02                0.02
#
#                      var_covelin law_10  mean_covelin law_5  \
# Timestamp
# 2020-01-10 04:14:00        1.203706e-35                0.02
#
#                      max_covelin law_5  min_covelin law_5  rms_covelin law_5  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02               0.02
#
#                      var_covelin law_5  mean_covelin law_3  max_covelin law_3  \
# Timestamp
# 2020-01-10 04:14:00                0.0                0.02               0.02
#
#                      min_covelin law_3  rms_covelin law_3  var_covelin law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02                0.0
#
#                      mean_crusher index_10  max_crusher index_10  \
# Timestamp
# 2020-01-10 04:14:00                19.7649               19.7649
#
#                      min_crusher index_10  rms_crusher index_10  \
# Timestamp
# 2020-01-10 04:14:00               19.7649               19.7649
#
#                      var_crusher index_10  mean_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00          1.262177e-29               19.7649
#
#                      max_crusher index_5  min_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      rms_crusher index_5  var_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00              19.7649                  0.0
#
#                      mean_crusher index_3  max_crusher index_3  \
# Timestamp
# 2020-01-10 04:14:00               19.7649              19.7649
#
#                      min_crusher index_3  rms_crusher index_3  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      var_crusher index_3  mean_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                  0.0                  15.4504
#
#                      max_ball work index_10  min_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504                 15.4504
#
#                      rms_ball work index_10  var_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504            3.155444e-30
#
#                      mean_ball work index_5  max_ball work index_5  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504                15.4504
#
#                      min_ball work index_5  rms_ball work index_5  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      var_ball work index_5  mean_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00           3.155444e-30                 15.4504
#
#                      max_ball work index_3  min_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      rms_ball work index_3  var_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                    0.0
#
#                      mean_bornite law_10  max_bornite law_10  \
# Timestamp
# 2020-01-10 04:14:00                 0.05                0.05
#
#                      min_bornite law_10  rms_bornite law_10  \
# Timestamp
# 2020-01-10 04:14:00                0.05                0.05
#
#                      var_bornite law_10  mean_bornite law_5  \
# Timestamp
# 2020-01-10 04:14:00                 0.0                0.05
#
#                      max_bornite law_5  min_bornite law_5  rms_bornite law_5  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05               0.05
#
#                      var_bornite law_5  mean_bornite law_3  max_bornite law_3  \
# Timestamp
# 2020-01-10 04:14:00                0.0                0.05               0.05
#
#                      min_bornite law_3  rms_bornite law_3  var_bornite law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05       4.814825e-35
#
#                      mean_charge cell_10  max_charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00           798.603167           809.23733
#
#                      min_charge cell_10  rms_charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00          790.204768          798.628312
#
#                      var_charge cell_10  mean_charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00           40.163516          793.205956
#
#                      max_charge cell_5  min_charge cell_5  rms_charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00         795.515964         790.204768         793.208306
#
#                      var_charge cell_5  mean_charge cell_3  max_charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00           3.728994          791.911514          793.61262
#
#                      min_charge cell_3  rms_charge cell_3  var_charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00         790.204768         791.912736           1.935592
#
#                      mean_speed_10  max_speed_10  min_speed_10  rms_speed_10  \
# Timestamp
# 2020-01-10 04:14:00       9.020702       9.06311      8.999591      9.020746
#
#                      var_speed_10  mean_speed_5  max_speed_5  min_speed_5  \
# Timestamp
# 2020-01-10 04:14:00      0.000782      9.000133     9.000854     8.999591
#
#                      rms_speed_5   var_speed_5  mean_speed_3  max_speed_3  \
# Timestamp
# 2020-01-10 04:14:00     9.000133  1.980423e-07      9.000013     9.000346
#
#                      min_speed_3  rms_speed_3   var_speed_3  \
# Timestamp
# 2020-01-10 04:14:00     8.999591     9.000013  9.913609e-08
#
#                      mean_granulometry_10  max_granulometry_10  \
# Timestamp
# 2020-01-10 04:14:00             48.723495            49.124744
#
#                      min_granulometry_10  rms_granulometry_10  \
# Timestamp
# 2020-01-10 04:14:00            48.465917            48.723982
#
#                      var_granulometry_10  mean_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00             0.047514            48.863517
#
#                      max_granulometry_5  min_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00           49.124744           48.614954
#
#                      rms_granulometry_5  var_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00           48.863898            0.037289
#
#                      mean_granulometry_3  max_granulometry_3  \
# Timestamp
# 2020-01-10 04:14:00            49.000679           49.124744
#
#                      min_granulometry_3  rms_granulometry_3  \
# Timestamp
# 2020-01-10 04:14:00           48.842239            49.00082
#
#                      var_granulometry_3  mean_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00            0.013892                 73.768634
#
#                      max_solid percentage_10  min_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00                74.485469                72.953594
#
#                      rms_solid percentage_10  var_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00                73.770287                 0.243801
#
#                      mean_solid percentage_5  max_solid percentage_5  \
# Timestamp
# 2020-01-10 04:14:00                74.156482               74.485469
#
#                      min_solid percentage_5  rms_solid percentage_5  \
# Timestamp
# 2020-01-10 04:14:00               73.714642                74.15704
#
#                      var_solid percentage_5  mean_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00                0.082646                74.343215
#
#                      max_solid percentage_3  min_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00               74.485469               74.086298
#
#                      rms_solid percentage_3  var_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00               74.343438                 0.03313
#
#                      mean_HH charge cell_10  max_HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                   850.0                  850.0
#
#                      min_HH charge cell_10  rms_HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  850.0                  850.0
#
#                      var_HH charge cell_10  mean_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    0.0                  850.0
#
#                      max_HH charge cell_5  min_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      rms_HH charge cell_5  var_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                   0.0
#
#                      mean_HH charge cell_3  max_HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                  850.0                 850.0
#
#                      min_HH charge cell_3  rms_HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      var_HH charge cell_3  mean_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                   770.0
#
#                      max_LL charge cell_10  min_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                  770.0
#
#                      rms_LL charge cell_10  var_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                    0.0
#
#                      mean_LL charge cell_5  max_LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                 770.0
#
#                      min_LL charge cell_5  rms_LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      var_LL charge cell_5  mean_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                  770.0
#
#                      max_LL charge cell_3  min_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      rms_LL charge cell_3  var_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                   0.0
#
#                      mean_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     51.396833
#
#                      max_delta HH charge cell_10  min_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    59.795232                     40.76267
#
#                      rms_delta HH charge cell_10  var_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    51.786079                    40.163516
#
#                      mean_delta HH charge cell_5  max_delta HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    56.794044                   59.795232
#
#                      min_delta HH charge cell_5  rms_delta HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                   54.484036                   56.826864
#
#                      var_delta HH charge cell_5  mean_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    3.728994                    58.088486
#
#                      max_delta HH charge cell_3  min_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   59.795232                    56.38738
#
#                      rms_delta HH charge cell_3  var_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   58.105144                    1.935592
#
#                      mean_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     28.603167
#
#                      max_delta LL charge cell_10  min_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     39.23733                    20.204768
#
#                      rms_delta LL charge cell_10  var_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    29.296837                    40.163516
#
#                      mean_delta LL charge cell_5  max_delta LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    23.205956                   25.515964
#
#                      min_delta LL charge cell_5  rms_delta LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                   20.204768                   23.286163
#
#                      var_delta LL charge cell_5  mean_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    3.728994                    21.911514
#
#                      max_delta LL charge cell_3  min_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    23.61262                   20.204768
#
#                      rms_delta LL charge cell_3  var_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   21.955638                    1.935592
#
#                      pyrite law_(t-1)  pyrite law_(t-2)  pyrite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               2.3
#
#                      pyrite law_(t-4)  pyrite law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3
#
#                      chalcopyrite law_(t-1)  chalcopyrite law_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      chalcopyrite law_(t-3)  chalcopyrite law_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      chalcopyrite law_(t-5)  chalcocite law_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                   0.5
#
#                      chalcocite law_(t-2)  chalcocite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      chalcocite law_(t-4)  chalcocite law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      covelin law_(t-1)  covelin law_(t-2)  covelin law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02               0.02
#
#                      covelin law_(t-4)  covelin law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02
#
#                      crusher index_(t-1)  crusher index_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      crusher index_(t-3)  crusher index_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      crusher index_(t-5)  ball work index_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649                15.4504
#
#                      ball work index_(t-2)  ball work index_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      ball work index_(t-4)  ball work index_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      bornite law_(t-1)  bornite law_(t-2)  bornite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05               0.05
#
#                      bornite law_(t-4)  bornite law_(t-5)  charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05         791.917155
#
#                      charge cell_(t-2)  charge cell_(t-3)  charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00          793.61262         794.779272         795.515964
#
#                      charge cell_(t-5)  speed_(t-1)  speed_(t-2)  speed_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00         798.234539     9.000346     9.000102     9.000854
#
#                      speed_(t-4)  speed_(t-5)  granulometry_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00     8.999773     9.000981           49.035053
#
#                      granulometry_(t-2)  granulometry_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00           48.842239           48.700594
#
#                      granulometry_(t-4)  granulometry_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00           48.614954           48.495837
#
#                      solid percentage_(t-1)  solid percentage_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00               74.457877               74.086298
#
#                      solid percentage_(t-3)  solid percentage_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00               74.038125               73.714642
#
#                      solid percentage_(t-5)  HH charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00               73.532265                 850.0
#
#                      HH charge cell_(t-2)  HH charge cell_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      HH charge cell_(t-4)  HH charge cell_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      LL charge cell_(t-1)  LL charge cell_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      LL charge cell_(t-3)  LL charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      LL charge cell_(t-5)  delta HH charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                   58.082845
#
#                      delta HH charge cell_(t-2)  delta HH charge cell_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                    56.38738                   55.220728
#
#                      delta HH charge cell_(t-4)  delta HH charge cell_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                   54.484036                   51.765461
#
#                      delta LL charge cell_(t-1)  delta LL charge cell_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                   21.917155                    23.61262
#
#                      delta LL charge cell_(t-3)  delta LL charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                   24.779272                   25.515964
#
#                      delta LL charge cell_(t-5)
# Timestamp
# 2020-01-10 04:14:00                   28.234539

# %% [markdown]
# # Correlación entre variables

# %%
# Se obtienen tags altamente correlacionados y matriz que permite visualizar cuales son los par de tags altamente correlacionados
collinearity, table_cor=corrkill(df_features,df_features.columns)

# %%
# Tags altamente correlacionados
table_cor

# %%
df_corr = df_features.dropna().corr()
corr_tph=pd.DataFrame(df_corr.abs().TPH.sort_values(ascending=False))

# %%
top_corr=corr_tph[corr_tph.TPH>=0.2]
top_corr

# %% [markdown]
# # Equilibrio de eventos de perdidas de TPH

# %%
# Entrenamiento
entrenamiento=pd.concat([df_features["2020-01":"2020-03"],df_features["2020-05"],df_features["2020-07":"2020-12"],df_features["2021-01":"2021-08"],df_features["2021-10"],df_features["2021-12"]])
entrenamiento.head(1)
# Out:
#                      sag power index  mean_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00          98.5569                  98.5569
#
#                      max_sag power index_10  min_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569                 98.5569
#
#                      rms_sag power index_10  var_sag power index_10  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569            2.019484e-28
#
#                      mean_sag power index_5  max_sag power index_5  \
# Timestamp
# 2020-01-10 04:14:00                 98.5569                98.5569
#
#                      min_sag power index_5  rms_sag power index_5  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      var_sag power index_5  mean_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                    0.0                 98.5569
#
#                      max_sag power index_3  min_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      rms_sag power index_3  var_sag power index_3  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                    0.0
#
#                      sag power index_(t-1)  sag power index_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      sag power index_(t-3)  sag power index_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                98.5569                98.5569
#
#                      sag power index_(t-5)  pyrite law  chalcopyrite law  \
# Timestamp
# 2020-01-10 04:14:00                98.5569         2.3              1.76
#
#                      chalcocite law  covelin law  crusher index  \
# Timestamp
# 2020-01-10 04:14:00             0.5         0.02        19.7649
#
#                      ball work index  bornite law  charge cell          TPH  \
# Timestamp
# 2020-01-10 04:14:00          15.4504         0.05   790.204768  3965.015072
#
#                         speed  HH TPH  granulometry  Edad  loss of TPH  \
# Timestamp
# 2020-01-10 04:14:00  8.999591  3950.0     49.124744   1.0          0.0
#
#                      solid percentage  HH charge cell  LL charge cell  \
# Timestamp
# 2020-01-10 04:14:00         74.485469           850.0           770.0
#
#                      delta HH charge cell  delta LL charge cell  \
# Timestamp
# 2020-01-10 04:14:00             59.795232             20.204768
#
#                      mean_pyrite law_10  max_pyrite law_10  min_pyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                 2.3                2.3                2.3
#
#                      rms_pyrite law_10  var_pyrite law_10  mean_pyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                2.3                0.0                2.3
#
#                      max_pyrite law_5  min_pyrite law_5  rms_pyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               2.3
#
#                      var_pyrite law_5  mean_pyrite law_3  max_pyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.0                2.3               2.3
#
#                      min_pyrite law_3  rms_pyrite law_3  var_pyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               0.0
#
#                      mean_chalcopyrite law_10  max_chalcopyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                      1.76                     1.76
#
#                      min_chalcopyrite law_10  rms_chalcopyrite law_10  \
# Timestamp
# 2020-01-10 04:14:00                     1.76                     1.76
#
#                      var_chalcopyrite law_10  mean_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00             4.930381e-32                     1.76
#
#                      max_chalcopyrite law_5  min_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      rms_chalcopyrite law_5  var_chalcopyrite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    1.76            4.930381e-32
#
#                      mean_chalcopyrite law_3  max_chalcopyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00                     1.76                    1.76
#
#                      min_chalcopyrite law_3  rms_chalcopyrite law_3  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      var_chalcopyrite law_3  mean_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                     0.0                     0.5
#
#                      max_chalcocite law_10  min_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                    0.5
#
#                      rms_chalcocite law_10  var_chalcocite law_10  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                    0.0
#
#                      mean_chalcocite law_5  max_chalcocite law_5  \
# Timestamp
# 2020-01-10 04:14:00                    0.5                   0.5
#
#                      min_chalcocite law_5  rms_chalcocite law_5  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      var_chalcocite law_5  mean_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                    0.5
#
#                      max_chalcocite law_3  min_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      rms_chalcocite law_3  var_chalcocite law_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.0
#
#                      mean_covelin law_10  max_covelin law_10  \
# Timestamp
# 2020-01-10 04:14:00                 0.02                0.02
#
#                      min_covelin law_10  rms_covelin law_10  \
# Timestamp
# 2020-01-10 04:14:00                0.02                0.02
#
#                      var_covelin law_10  mean_covelin law_5  \
# Timestamp
# 2020-01-10 04:14:00        1.203706e-35                0.02
#
#                      max_covelin law_5  min_covelin law_5  rms_covelin law_5  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02               0.02
#
#                      var_covelin law_5  mean_covelin law_3  max_covelin law_3  \
# Timestamp
# 2020-01-10 04:14:00                0.0                0.02               0.02
#
#                      min_covelin law_3  rms_covelin law_3  var_covelin law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02                0.0
#
#                      mean_crusher index_10  max_crusher index_10  \
# Timestamp
# 2020-01-10 04:14:00                19.7649               19.7649
#
#                      min_crusher index_10  rms_crusher index_10  \
# Timestamp
# 2020-01-10 04:14:00               19.7649               19.7649
#
#                      var_crusher index_10  mean_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00          1.262177e-29               19.7649
#
#                      max_crusher index_5  min_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      rms_crusher index_5  var_crusher index_5  \
# Timestamp
# 2020-01-10 04:14:00              19.7649                  0.0
#
#                      mean_crusher index_3  max_crusher index_3  \
# Timestamp
# 2020-01-10 04:14:00               19.7649              19.7649
#
#                      min_crusher index_3  rms_crusher index_3  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      var_crusher index_3  mean_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                  0.0                  15.4504
#
#                      max_ball work index_10  min_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504                 15.4504
#
#                      rms_ball work index_10  var_ball work index_10  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504            3.155444e-30
#
#                      mean_ball work index_5  max_ball work index_5  \
# Timestamp
# 2020-01-10 04:14:00                 15.4504                15.4504
#
#                      min_ball work index_5  rms_ball work index_5  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      var_ball work index_5  mean_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00           3.155444e-30                 15.4504
#
#                      max_ball work index_3  min_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      rms_ball work index_3  var_ball work index_3  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                    0.0
#
#                      mean_bornite law_10  max_bornite law_10  \
# Timestamp
# 2020-01-10 04:14:00                 0.05                0.05
#
#                      min_bornite law_10  rms_bornite law_10  \
# Timestamp
# 2020-01-10 04:14:00                0.05                0.05
#
#                      var_bornite law_10  mean_bornite law_5  \
# Timestamp
# 2020-01-10 04:14:00                 0.0                0.05
#
#                      max_bornite law_5  min_bornite law_5  rms_bornite law_5  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05               0.05
#
#                      var_bornite law_5  mean_bornite law_3  max_bornite law_3  \
# Timestamp
# 2020-01-10 04:14:00                0.0                0.05               0.05
#
#                      min_bornite law_3  rms_bornite law_3  var_bornite law_3  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05       4.814825e-35
#
#                      mean_charge cell_10  max_charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00           798.603167           809.23733
#
#                      min_charge cell_10  rms_charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00          790.204768          798.628312
#
#                      var_charge cell_10  mean_charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00           40.163516          793.205956
#
#                      max_charge cell_5  min_charge cell_5  rms_charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00         795.515964         790.204768         793.208306
#
#                      var_charge cell_5  mean_charge cell_3  max_charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00           3.728994          791.911514          793.61262
#
#                      min_charge cell_3  rms_charge cell_3  var_charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00         790.204768         791.912736           1.935592
#
#                      mean_speed_10  max_speed_10  min_speed_10  rms_speed_10  \
# Timestamp
# 2020-01-10 04:14:00       9.020702       9.06311      8.999591      9.020746
#
#                      var_speed_10  mean_speed_5  max_speed_5  min_speed_5  \
# Timestamp
# 2020-01-10 04:14:00      0.000782      9.000133     9.000854     8.999591
#
#                      rms_speed_5   var_speed_5  mean_speed_3  max_speed_3  \
# Timestamp
# 2020-01-10 04:14:00     9.000133  1.980423e-07      9.000013     9.000346
#
#                      min_speed_3  rms_speed_3   var_speed_3  \
# Timestamp
# 2020-01-10 04:14:00     8.999591     9.000013  9.913609e-08
#
#                      mean_granulometry_10  max_granulometry_10  \
# Timestamp
# 2020-01-10 04:14:00             48.723495            49.124744
#
#                      min_granulometry_10  rms_granulometry_10  \
# Timestamp
# 2020-01-10 04:14:00            48.465917            48.723982
#
#                      var_granulometry_10  mean_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00             0.047514            48.863517
#
#                      max_granulometry_5  min_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00           49.124744           48.614954
#
#                      rms_granulometry_5  var_granulometry_5  \
# Timestamp
# 2020-01-10 04:14:00           48.863898            0.037289
#
#                      mean_granulometry_3  max_granulometry_3  \
# Timestamp
# 2020-01-10 04:14:00            49.000679           49.124744
#
#                      min_granulometry_3  rms_granulometry_3  \
# Timestamp
# 2020-01-10 04:14:00           48.842239            49.00082
#
#                      var_granulometry_3  mean_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00            0.013892                 73.768634
#
#                      max_solid percentage_10  min_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00                74.485469                72.953594
#
#                      rms_solid percentage_10  var_solid percentage_10  \
# Timestamp
# 2020-01-10 04:14:00                73.770287                 0.243801
#
#                      mean_solid percentage_5  max_solid percentage_5  \
# Timestamp
# 2020-01-10 04:14:00                74.156482               74.485469
#
#                      min_solid percentage_5  rms_solid percentage_5  \
# Timestamp
# 2020-01-10 04:14:00               73.714642                74.15704
#
#                      var_solid percentage_5  mean_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00                0.082646                74.343215
#
#                      max_solid percentage_3  min_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00               74.485469               74.086298
#
#                      rms_solid percentage_3  var_solid percentage_3  \
# Timestamp
# 2020-01-10 04:14:00               74.343438                 0.03313
#
#                      mean_HH charge cell_10  max_HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                   850.0                  850.0
#
#                      min_HH charge cell_10  rms_HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  850.0                  850.0
#
#                      var_HH charge cell_10  mean_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    0.0                  850.0
#
#                      max_HH charge cell_5  min_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      rms_HH charge cell_5  var_HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                   0.0
#
#                      mean_HH charge cell_3  max_HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                  850.0                 850.0
#
#                      min_HH charge cell_3  rms_HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      var_HH charge cell_3  mean_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                   770.0
#
#                      max_LL charge cell_10  min_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                  770.0
#
#                      rms_LL charge cell_10  var_LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                    0.0
#
#                      mean_LL charge cell_5  max_LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                  770.0                 770.0
#
#                      min_LL charge cell_5  rms_LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      var_LL charge cell_5  mean_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   0.0                  770.0
#
#                      max_LL charge cell_3  min_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      rms_LL charge cell_3  var_LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                   0.0
#
#                      mean_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     51.396833
#
#                      max_delta HH charge cell_10  min_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    59.795232                     40.76267
#
#                      rms_delta HH charge cell_10  var_delta HH charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    51.786079                    40.163516
#
#                      mean_delta HH charge cell_5  max_delta HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    56.794044                   59.795232
#
#                      min_delta HH charge cell_5  rms_delta HH charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                   54.484036                   56.826864
#
#                      var_delta HH charge cell_5  mean_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    3.728994                    58.088486
#
#                      max_delta HH charge cell_3  min_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   59.795232                    56.38738
#
#                      rms_delta HH charge cell_3  var_delta HH charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   58.105144                    1.935592
#
#                      mean_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     28.603167
#
#                      max_delta LL charge cell_10  min_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                     39.23733                    20.204768
#
#                      rms_delta LL charge cell_10  var_delta LL charge cell_10  \
# Timestamp
# 2020-01-10 04:14:00                    29.296837                    40.163516
#
#                      mean_delta LL charge cell_5  max_delta LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                    23.205956                   25.515964
#
#                      min_delta LL charge cell_5  rms_delta LL charge cell_5  \
# Timestamp
# 2020-01-10 04:14:00                   20.204768                   23.286163
#
#                      var_delta LL charge cell_5  mean_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    3.728994                    21.911514
#
#                      max_delta LL charge cell_3  min_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                    23.61262                   20.204768
#
#                      rms_delta LL charge cell_3  var_delta LL charge cell_3  \
# Timestamp
# 2020-01-10 04:14:00                   21.955638                    1.935592
#
#                      pyrite law_(t-1)  pyrite law_(t-2)  pyrite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3               2.3
#
#                      pyrite law_(t-4)  pyrite law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00               2.3               2.3
#
#                      chalcopyrite law_(t-1)  chalcopyrite law_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      chalcopyrite law_(t-3)  chalcopyrite law_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                    1.76
#
#                      chalcopyrite law_(t-5)  chalcocite law_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00                    1.76                   0.5
#
#                      chalcocite law_(t-2)  chalcocite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      chalcocite law_(t-4)  chalcocite law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                   0.5                   0.5
#
#                      covelin law_(t-1)  covelin law_(t-2)  covelin law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02               0.02
#
#                      covelin law_(t-4)  covelin law_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00               0.02               0.02
#
#                      crusher index_(t-1)  crusher index_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      crusher index_(t-3)  crusher index_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649              19.7649
#
#                      crusher index_(t-5)  ball work index_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00              19.7649                15.4504
#
#                      ball work index_(t-2)  ball work index_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      ball work index_(t-4)  ball work index_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                15.4504                15.4504
#
#                      bornite law_(t-1)  bornite law_(t-2)  bornite law_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05               0.05
#
#                      bornite law_(t-4)  bornite law_(t-5)  charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00               0.05               0.05         791.917155
#
#                      charge cell_(t-2)  charge cell_(t-3)  charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00          793.61262         794.779272         795.515964
#
#                      charge cell_(t-5)  speed_(t-1)  speed_(t-2)  speed_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00         798.234539     9.000346     9.000102     9.000854
#
#                      speed_(t-4)  speed_(t-5)  granulometry_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00     8.999773     9.000981           49.035053
#
#                      granulometry_(t-2)  granulometry_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00           48.842239           48.700594
#
#                      granulometry_(t-4)  granulometry_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00           48.614954           48.495837
#
#                      solid percentage_(t-1)  solid percentage_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00               74.457877               74.086298
#
#                      solid percentage_(t-3)  solid percentage_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00               74.038125               73.714642
#
#                      solid percentage_(t-5)  HH charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00               73.532265                 850.0
#
#                      HH charge cell_(t-2)  HH charge cell_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      HH charge cell_(t-4)  HH charge cell_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                 850.0                 850.0
#
#                      LL charge cell_(t-1)  LL charge cell_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      LL charge cell_(t-3)  LL charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                 770.0
#
#                      LL charge cell_(t-5)  delta HH charge cell_(t-1)  \
# Timestamp
# 2020-01-10 04:14:00                 770.0                   58.082845
#
#                      delta HH charge cell_(t-2)  delta HH charge cell_(t-3)  \
# Timestamp
# 2020-01-10 04:14:00                    56.38738                   55.220728
#
#                      delta HH charge cell_(t-4)  delta HH charge cell_(t-5)  \
# Timestamp
# 2020-01-10 04:14:00                   54.484036                   51.765461
#
#                      delta LL charge cell_(t-1)  delta LL charge cell_(t-2)  \
# Timestamp
# 2020-01-10 04:14:00                   21.917155                    23.61262
#
#                      delta LL charge cell_(t-3)  delta LL charge cell_(t-4)  \
# Timestamp
# 2020-01-10 04:14:00                   24.779272                   25.515964
#
#                      delta LL charge cell_(t-5)
# Timestamp
# 2020-01-10 04:14:00                   28.234539

# %%
# Validación
validacion=pd.concat([df_features["2020-06"],df_features["2021-11"]])
validacion.head(1)
# Out:
#             sag power index  mean_sag power index_10  max_sag power index_10  \
# Timestamp
# 2020-06-01         172.6142                159.57176                172.6142
#
#             min_sag power index_10  rms_sag power index_10  \
# Timestamp
# 2020-06-01                158.1226              159.630972
#
#             var_sag power index_10  mean_sag power index_5  \
# Timestamp
# 2020-06-01               18.900582               161.02092
#
#             max_sag power index_5  min_sag power index_5  \
# Timestamp
# 2020-06-01               172.6142               158.1226
#
#             rms_sag power index_5  var_sag power index_5  \
# Timestamp
# 2020-06-01             161.125224              33.601035
#
#             mean_sag power index_3  max_sag power index_3  \
# Timestamp
# 2020-06-01              162.953133               172.6142
#
#             min_sag power index_3  rms_sag power index_3  \
# Timestamp
# 2020-06-01               158.1226             163.096265
#
#             var_sag power index_3  sag power index_(t-1)  \
# Timestamp
# 2020-06-01              46.668105               158.1226
#
#             sag power index_(t-2)  sag power index_(t-3)  \
# Timestamp
# 2020-06-01               158.1226               158.1226
#
#             sag power index_(t-4)  sag power index_(t-5)  pyrite law  \
# Timestamp
# 2020-06-01               158.1226               158.1226        1.11
#
#             chalcopyrite law  chalcocite law  covelin law  crusher index  \
# Timestamp
# 2020-06-01              0.98            0.45          0.0        23.6028
#
#             ball work index  bornite law  charge cell          TPH     speed  \
# Timestamp
# 2020-06-01          18.1765          0.0   811.822555  3553.885205  8.877953
#
#             HH TPH  granulometry  Edad  loss of TPH  solid percentage  \
# Timestamp
# 2020-06-01  4400.0      52.80404   0.0          1.0         65.044377
#
#             HH charge cell  LL charge cell  delta HH charge cell  \
# Timestamp
# 2020-06-01           820.0           740.0              8.177445
#
#             delta LL charge cell  mean_pyrite law_10  max_pyrite law_10  \
# Timestamp
# 2020-06-01             71.822555               1.479               1.52
#
#             min_pyrite law_10  rms_pyrite law_10  var_pyrite law_10  \
# Timestamp
# 2020-06-01               1.11           1.484106           0.015129
#
#             mean_pyrite law_5  max_pyrite law_5  min_pyrite law_5  \
# Timestamp
# 2020-06-01              1.438              1.52              1.11
#
#             rms_pyrite law_5  var_pyrite law_5  mean_pyrite law_3  \
# Timestamp
# 2020-06-01          1.447322          0.026896           1.383333
#
#             max_pyrite law_3  min_pyrite law_3  rms_pyrite law_3  \
# Timestamp
# 2020-06-01              1.52              1.11           1.39677
#
#             var_pyrite law_3  mean_chalcopyrite law_10  \
# Timestamp
# 2020-06-01          0.037356                     1.178
#
#             max_chalcopyrite law_10  min_chalcopyrite law_10  \
# Timestamp
# 2020-06-01                      1.2                     0.98
#
#             rms_chalcopyrite law_10  var_chalcopyrite law_10  \
# Timestamp
# 2020-06-01                 1.179847                 0.004356
#
#             mean_chalcopyrite law_5  max_chalcopyrite law_5  \
# Timestamp
# 2020-06-01                    1.156                     1.2
#
#             min_chalcopyrite law_5  rms_chalcopyrite law_5  \
# Timestamp
# 2020-06-01                    0.98                1.159345
#
#             var_chalcopyrite law_5  mean_chalcopyrite law_3  \
# Timestamp
# 2020-06-01                0.007744                 1.126667
#
#             max_chalcopyrite law_3  min_chalcopyrite law_3  \
# Timestamp
# 2020-06-01                     1.2                    0.98
#
#             rms_chalcopyrite law_3  var_chalcopyrite law_3  \
# Timestamp
# 2020-06-01                 1.13143                0.010756
#
#             mean_chalcocite law_10  max_chalcocite law_10  \
# Timestamp
# 2020-06-01                   0.504                   0.51
#
#             min_chalcocite law_10  rms_chalcocite law_10  \
# Timestamp
# 2020-06-01                   0.45               0.504321
#
#             var_chalcocite law_10  mean_chalcocite law_5  \
# Timestamp
# 2020-06-01               0.000324                  0.498
#
#             max_chalcocite law_5  min_chalcocite law_5  rms_chalcocite law_5  \
# Timestamp
# 2020-06-01                  0.51                  0.45              0.498578
#
#             var_chalcocite law_5  mean_chalcocite law_3  max_chalcocite law_3  \
# Timestamp
# 2020-06-01              0.000576                   0.49                  0.51
#
#             min_chalcocite law_3  rms_chalcocite law_3  var_chalcocite law_3  \
# Timestamp
# 2020-06-01                  0.45              0.490816                0.0008
#
#             mean_covelin law_10  max_covelin law_10  min_covelin law_10  \
# Timestamp
# 2020-06-01                0.009                0.01                 0.0
#
#             rms_covelin law_10  var_covelin law_10  mean_covelin law_5  \
# Timestamp
# 2020-06-01            0.009487            0.000009               0.008
#
#             max_covelin law_5  min_covelin law_5  rms_covelin law_5  \
# Timestamp
# 2020-06-01               0.01                0.0           0.008944
#
#             var_covelin law_5  mean_covelin law_3  max_covelin law_3  \
# Timestamp
# 2020-06-01           0.000016            0.006667               0.01
#
#             min_covelin law_3  rms_covelin law_3  var_covelin law_3  \
# Timestamp
# 2020-06-01                0.0           0.008165           0.000022
#
#             mean_crusher index_10  max_crusher index_10  min_crusher index_10  \
# Timestamp
# 2020-06-01               23.35512               23.6028               23.3276
#
#             rms_crusher index_10  var_crusher index_10  mean_crusher index_5  \
# Timestamp
# 2020-06-01             23.355266              0.006816              23.38264
#
#             max_crusher index_5  min_crusher index_5  rms_crusher index_5  \
# Timestamp
# 2020-06-01              23.6028              23.3276            23.382899
#
#             var_crusher index_5  mean_crusher index_3  max_crusher index_3  \
# Timestamp
# 2020-06-01             0.012118             23.419333              23.6028
#
#             min_crusher index_3  rms_crusher index_3  var_crusher index_3  \
# Timestamp
# 2020-06-01              23.3276            23.419693              0.01683
#
#             mean_ball work index_10  max_ball work index_10  \
# Timestamp
# 2020-06-01                 17.89588                 18.1765
#
#             min_ball work index_10  rms_ball work index_10  \
# Timestamp
# 2020-06-01                 17.8647               17.896124
#
#             var_ball work index_10  mean_ball work index_5  \
# Timestamp
# 2020-06-01                 0.00875                17.92706
#
#             max_ball work index_5  min_ball work index_5  \
# Timestamp
# 2020-06-01                18.1765                17.8647
#
#             rms_ball work index_5  var_ball work index_5  \
# Timestamp
# 2020-06-01              17.927494               0.015555
#
#             mean_ball work index_3  max_ball work index_3  \
# Timestamp
# 2020-06-01               17.968633                18.1765
#
#             min_ball work index_3  rms_ball work index_3  \
# Timestamp
# 2020-06-01                17.8647              17.969234
#
#             var_ball work index_3  mean_bornite law_10  max_bornite law_10  \
# Timestamp
# 2020-06-01               0.021604                  0.0                 0.0
#
#             min_bornite law_10  rms_bornite law_10  var_bornite law_10  \
# Timestamp
# 2020-06-01                 0.0                 0.0                 0.0
#
#             mean_bornite law_5  max_bornite law_5  min_bornite law_5  \
# Timestamp
# 2020-06-01                 0.0                0.0                0.0
#
#             rms_bornite law_5  var_bornite law_5  mean_bornite law_3  \
# Timestamp
# 2020-06-01                0.0                0.0                 0.0
#
#             max_bornite law_3  min_bornite law_3  rms_bornite law_3  \
# Timestamp
# 2020-06-01                0.0                0.0                0.0
#
#             var_bornite law_3  mean_charge cell_10  max_charge cell_10  \
# Timestamp
# 2020-06-01                0.0           812.741714          820.841222
#
#             min_charge cell_10  rms_charge cell_10  var_charge cell_10  \
# Timestamp
# 2020-06-01          808.370729          812.753293           18.820933
#
#             mean_charge cell_5  max_charge cell_5  min_charge cell_5  \
# Timestamp
# 2020-06-01           809.62674         811.822555         808.370729
#
#             rms_charge cell_5  var_charge cell_5  mean_charge cell_3  \
# Timestamp
# 2020-06-01         809.627834           1.771907          810.234924
#
#             max_charge cell_3  min_charge cell_3  rms_charge cell_3  \
# Timestamp
# 2020-06-01         811.822555         808.370729         810.236173
#
#             var_charge cell_3  mean_speed_10  max_speed_10  min_speed_10  \
# Timestamp
# 2020-06-01           2.024094        8.87382      8.877953       8.86769
#
#             rms_speed_10  var_speed_10  mean_speed_5  max_speed_5  \
# Timestamp
# 2020-06-01       8.87382      0.000008      8.874422     8.877953
#
#             min_speed_5  rms_speed_5  var_speed_5  mean_speed_3  max_speed_3  \
# Timestamp
# 2020-06-01     8.870746     8.874423     0.000006      8.874151     8.877953
#
#             min_speed_3  rms_speed_3  var_speed_3  mean_granulometry_10  \
# Timestamp
# 2020-06-01     8.870746     8.874151     0.000009             51.649463
#
#             max_granulometry_10  min_granulometry_10  rms_granulometry_10  \
# Timestamp
# 2020-06-01             52.80404            50.482627            51.653938
#
#             var_granulometry_10  mean_granulometry_5  max_granulometry_5  \
# Timestamp
# 2020-06-01             0.462283            52.190431            52.80404
#
#             min_granulometry_5  rms_granulometry_5  var_granulometry_5  \
# Timestamp
# 2020-06-01           51.628653           52.192141            0.178476
#
#             mean_granulometry_3  max_granulometry_3  min_granulometry_3  \
# Timestamp
# 2020-06-01            52.491593            52.80404           52.191338
#
#             rms_granulometry_3  var_granulometry_3  mean_solid percentage_10  \
# Timestamp
# 2020-06-01            52.49219            0.062642                 65.042908
#
#             max_solid percentage_10  min_solid percentage_10  \
# Timestamp
# 2020-06-01                65.252047                64.838669
#
#             rms_solid percentage_10  var_solid percentage_10  \
# Timestamp
# 2020-06-01                65.043002                 0.012208
#
#             mean_solid percentage_5  max_solid percentage_5  \
# Timestamp
# 2020-06-01                65.098793               65.252047
#
#             min_solid percentage_5  rms_solid percentage_5  \
# Timestamp
# 2020-06-01               64.977265               65.098856
#
#             var_solid percentage_5  mean_solid percentage_3  \
# Timestamp
# 2020-06-01                0.008295                 65.09123
#
#             max_solid percentage_3  min_solid percentage_3  \
# Timestamp
# 2020-06-01               65.252047               64.977265
#
#             rms_solid percentage_3  var_solid percentage_3  \
# Timestamp
# 2020-06-01               65.091335                0.013682
#
#             mean_HH charge cell_10  max_HH charge cell_10  \
# Timestamp
# 2020-06-01                   820.0                  820.0
#
#             min_HH charge cell_10  rms_HH charge cell_10  \
# Timestamp
# 2020-06-01                  820.0                  820.0
#
#             var_HH charge cell_10  mean_HH charge cell_5  \
# Timestamp
# 2020-06-01                    0.0                  820.0
#
#             max_HH charge cell_5  min_HH charge cell_5  rms_HH charge cell_5  \
# Timestamp
# 2020-06-01                 820.0                 820.0                 820.0
#
#             var_HH charge cell_5  mean_HH charge cell_3  max_HH charge cell_3  \
# Timestamp
# 2020-06-01                   0.0                  820.0                 820.0
#
#             min_HH charge cell_3  rms_HH charge cell_3  var_HH charge cell_3  \
# Timestamp
# 2020-06-01                 820.0                 820.0                   0.0
#
#             mean_LL charge cell_10  max_LL charge cell_10  \
# Timestamp
# 2020-06-01                   740.0                  740.0
#
#             min_LL charge cell_10  rms_LL charge cell_10  \
# Timestamp
# 2020-06-01                  740.0                  740.0
#
#             var_LL charge cell_10  mean_LL charge cell_5  \
# Timestamp
# 2020-06-01                    0.0                  740.0
#
#             max_LL charge cell_5  min_LL charge cell_5  rms_LL charge cell_5  \
# Timestamp
# 2020-06-01                 740.0                 740.0                 740.0
#
#             var_LL charge cell_5  mean_LL charge cell_3  max_LL charge cell_3  \
# Timestamp
# 2020-06-01                   0.0                  740.0                 740.0
#
#             min_LL charge cell_3  rms_LL charge cell_3  var_LL charge cell_3  \
# Timestamp
# 2020-06-01                 740.0                 740.0                   0.0
#
#             mean_delta HH charge cell_10  max_delta HH charge cell_10  \
# Timestamp
# 2020-06-01                      7.258286                    11.629271
#
#             min_delta HH charge cell_10  rms_delta HH charge cell_10  \
# Timestamp
# 2020-06-01                    -0.841222                     8.455983
#
#             var_delta HH charge cell_10  mean_delta HH charge cell_5  \
# Timestamp
# 2020-06-01                    18.820933                     10.37326
#
#             max_delta HH charge cell_5  min_delta HH charge cell_5  \
# Timestamp
# 2020-06-01                   11.629271                    8.177445
#
#             rms_delta HH charge cell_5  var_delta HH charge cell_5  \
# Timestamp
# 2020-06-01                   10.458319                    1.771907
#
#             mean_delta HH charge cell_3  max_delta HH charge cell_3  \
# Timestamp
# 2020-06-01                     9.765076                   11.629271
#
#             min_delta HH charge cell_3  rms_delta HH charge cell_3  \
# Timestamp
# 2020-06-01                    8.177445                    9.868171
#
#             var_delta HH charge cell_3  mean_delta LL charge cell_10  \
# Timestamp
# 2020-06-01                    2.024094                     72.741714
#
#             max_delta LL charge cell_10  min_delta LL charge cell_10  \
# Timestamp
# 2020-06-01                    80.841222                    68.370729
#
#             rms_delta LL charge cell_10  var_delta LL charge cell_10  \
# Timestamp
# 2020-06-01                    72.870967                    18.820933
#
#             mean_delta LL charge cell_5  max_delta LL charge cell_5  \
# Timestamp
# 2020-06-01                     69.62674                   71.822555
#
#             min_delta LL charge cell_5  rms_delta LL charge cell_5  \
# Timestamp
# 2020-06-01                   68.370729                   69.639463
#
#             var_delta LL charge cell_5  mean_delta LL charge cell_3  \
# Timestamp
# 2020-06-01                    1.771907                    70.234924
#
#             max_delta LL charge cell_3  min_delta LL charge cell_3  \
# Timestamp
# 2020-06-01                   71.822555                   68.370729
#
#             rms_delta LL charge cell_3  var_delta LL charge cell_3  \
# Timestamp
# 2020-06-01                   70.249332                    2.024094
#
#             pyrite law_(t-1)  pyrite law_(t-2)  pyrite law_(t-3)  \
# Timestamp
# 2020-06-01              1.52              1.52              1.52
#
#             pyrite law_(t-4)  pyrite law_(t-5)  chalcopyrite law_(t-1)  \
# Timestamp
# 2020-06-01              1.52              1.52                     1.2
#
#             chalcopyrite law_(t-2)  chalcopyrite law_(t-3)  \
# Timestamp
# 2020-06-01                     1.2                     1.2
#
#             chalcopyrite law_(t-4)  chalcopyrite law_(t-5)  \
# Timestamp
# 2020-06-01                     1.2                     1.2
#
#             chalcocite law_(t-1)  chalcocite law_(t-2)  chalcocite law_(t-3)  \
# Timestamp
# 2020-06-01                  0.51                  0.51                  0.51
#
#             chalcocite law_(t-4)  chalcocite law_(t-5)  covelin law_(t-1)  \
# Timestamp
# 2020-06-01                  0.51                  0.51               0.01
#
#             covelin law_(t-2)  covelin law_(t-3)  covelin law_(t-4)  \
# Timestamp
# 2020-06-01               0.01               0.01               0.01
#
#             covelin law_(t-5)  crusher index_(t-1)  crusher index_(t-2)  \
# Timestamp
# 2020-06-01               0.01              23.3276              23.3276
#
#             crusher index_(t-3)  crusher index_(t-4)  crusher index_(t-5)  \
# Timestamp
# 2020-06-01              23.3276              23.3276              23.3276
#
#             ball work index_(t-1)  ball work index_(t-2)  \
# Timestamp
# 2020-06-01                17.8647                17.8647
#
#             ball work index_(t-3)  ball work index_(t-4)  \
# Timestamp
# 2020-06-01                17.8647                17.8647
#
#             ball work index_(t-5)  bornite law_(t-1)  bornite law_(t-2)  \
# Timestamp
# 2020-06-01                17.8647                0.0                0.0
#
#             bornite law_(t-3)  bornite law_(t-4)  bornite law_(t-5)  \
# Timestamp
# 2020-06-01                0.0                0.0                0.0
#
#             charge cell_(t-1)  charge cell_(t-2)  charge cell_(t-3)  \
# Timestamp
# 2020-06-01         810.511489         808.370729         808.633576
#
#             charge cell_(t-4)  charge cell_(t-5)  speed_(t-1)  speed_(t-2)  \
# Timestamp
# 2020-06-01          808.79535         810.076823     8.873753     8.870746
#
#             speed_(t-3)  speed_(t-4)  speed_(t-5)  granulometry_(t-1)  \
# Timestamp
# 2020-06-01      8.87415      8.87551      8.86769           52.479402
#
#             granulometry_(t-2)  granulometry_(t-3)  granulometry_(t-4)  \
# Timestamp
# 2020-06-01           52.191338           51.848723           51.628653
#
#             granulometry_(t-5)  solid percentage_(t-1)  \
# Timestamp
# 2020-06-01           51.563434               65.252047
#
#             solid percentage_(t-2)  solid percentage_(t-3)  \
# Timestamp
# 2020-06-01               64.977265               65.110449
#
#             solid percentage_(t-4)  solid percentage_(t-5)  \
# Timestamp
# 2020-06-01               65.109825               65.138229
#
#             HH charge cell_(t-1)  HH charge cell_(t-2)  HH charge cell_(t-3)  \
# Timestamp
# 2020-06-01                 820.0                 820.0                 820.0
#
#             HH charge cell_(t-4)  HH charge cell_(t-5)  LL charge cell_(t-1)  \
# Timestamp
# 2020-06-01                 820.0                 820.0                 740.0
#
#             LL charge cell_(t-2)  LL charge cell_(t-3)  LL charge cell_(t-4)  \
# Timestamp
# 2020-06-01                 740.0                 740.0                 740.0
#
#             LL charge cell_(t-5)  delta HH charge cell_(t-1)  \
# Timestamp
# 2020-06-01                 740.0                    9.488511
#
#             delta HH charge cell_(t-2)  delta HH charge cell_(t-3)  \
# Timestamp
# 2020-06-01                   11.629271                   11.366424
#
#             delta HH charge cell_(t-4)  delta HH charge cell_(t-5)  \
# Timestamp
# 2020-06-01                    11.20465                    9.923177
#
#             delta LL charge cell_(t-1)  delta LL charge cell_(t-2)  \
# Timestamp
# 2020-06-01                   70.511489                   68.370729
#
#             delta LL charge cell_(t-3)  delta LL charge cell_(t-4)  \
# Timestamp
# 2020-06-01                   68.633576                    68.79535
#
#             delta LL charge cell_(t-5)
# Timestamp
# 2020-06-01                   70.076823

# %%
# Test
test=pd.concat([df_features["2020-04"],df_features["2021-09"],df_features["2022"]])
test.head(1)
# Out:
#             sag power index  mean_sag power index_10  max_sag power index_10  \
# Timestamp
# 2020-04-01            119.6                    119.6                   119.6
#
#             min_sag power index_10  rms_sag power index_10  \
# Timestamp
# 2020-04-01                   119.6                   119.6
#
#             var_sag power index_10  mean_sag power index_5  \
# Timestamp
# 2020-04-01            2.019484e-28                   119.6
#
#             max_sag power index_5  min_sag power index_5  \
# Timestamp
# 2020-04-01                  119.6                  119.6
#
#             rms_sag power index_5  var_sag power index_5  \
# Timestamp
# 2020-04-01                  119.6                    0.0
#
#             mean_sag power index_3  max_sag power index_3  \
# Timestamp
# 2020-04-01                   119.6                  119.6
#
#             min_sag power index_3  rms_sag power index_3  \
# Timestamp
# 2020-04-01                  119.6                  119.6
#
#             var_sag power index_3  sag power index_(t-1)  \
# Timestamp
# 2020-04-01           2.019484e-28                  119.6
#
#             sag power index_(t-2)  sag power index_(t-3)  \
# Timestamp
# 2020-04-01                  119.6                  119.6
#
#             sag power index_(t-4)  sag power index_(t-5)  pyrite law  \
# Timestamp
# 2020-04-01                  119.6                  119.6        3.14
#
#             chalcopyrite law  chalcocite law  covelin law  crusher index  \
# Timestamp
# 2020-04-01               1.6            0.39         0.03           19.4
#
#             ball work index  bornite law  charge cell          TPH     speed  \
# Timestamp
# 2020-04-01             17.0         0.02    755.74875  4188.172694  9.249551
#
#             HH TPH  granulometry  Edad  loss of TPH  solid percentage  \
# Timestamp
# 2020-04-01  3800.0     30.530144   2.0          0.0          65.03294
#
#             HH charge cell  LL charge cell  delta HH charge cell  \
# Timestamp
# 2020-04-01           840.0           760.0              84.25125
#
#             delta LL charge cell  mean_pyrite law_10  max_pyrite law_10  \
# Timestamp
# 2020-04-01              -4.25125                3.14               3.14
#
#             min_pyrite law_10  rms_pyrite law_10  var_pyrite law_10  \
# Timestamp
# 2020-04-01               3.14               3.14                0.0
#
#             mean_pyrite law_5  max_pyrite law_5  min_pyrite law_5  \
# Timestamp
# 2020-04-01               3.14              3.14              3.14
#
#             rms_pyrite law_5  var_pyrite law_5  mean_pyrite law_3  \
# Timestamp
# 2020-04-01              3.14               0.0               3.14
#
#             max_pyrite law_3  min_pyrite law_3  rms_pyrite law_3  \
# Timestamp
# 2020-04-01              3.14              3.14              3.14
#
#             var_pyrite law_3  mean_chalcopyrite law_10  \
# Timestamp
# 2020-04-01               0.0                       1.6
#
#             max_chalcopyrite law_10  min_chalcopyrite law_10  \
# Timestamp
# 2020-04-01                      1.6                      1.6
#
#             rms_chalcopyrite law_10  var_chalcopyrite law_10  \
# Timestamp
# 2020-04-01                      1.6                      0.0
#
#             mean_chalcopyrite law_5  max_chalcopyrite law_5  \
# Timestamp
# 2020-04-01                      1.6                     1.6
#
#             min_chalcopyrite law_5  rms_chalcopyrite law_5  \
# Timestamp
# 2020-04-01                     1.6                     1.6
#
#             var_chalcopyrite law_5  mean_chalcopyrite law_3  \
# Timestamp
# 2020-04-01                     0.0                      1.6
#
#             max_chalcopyrite law_3  min_chalcopyrite law_3  \
# Timestamp
# 2020-04-01                     1.6                     1.6
#
#             rms_chalcopyrite law_3  var_chalcopyrite law_3  \
# Timestamp
# 2020-04-01                     1.6            4.930381e-32
#
#             mean_chalcocite law_10  max_chalcocite law_10  \
# Timestamp
# 2020-04-01                    0.39                   0.39
#
#             min_chalcocite law_10  rms_chalcocite law_10  \
# Timestamp
# 2020-04-01                   0.39                   0.39
#
#             var_chalcocite law_10  mean_chalcocite law_5  \
# Timestamp
# 2020-04-01                    0.0                   0.39
#
#             max_chalcocite law_5  min_chalcocite law_5  rms_chalcocite law_5  \
# Timestamp
# 2020-04-01                  0.39                  0.39                  0.39
#
#             var_chalcocite law_5  mean_chalcocite law_3  max_chalcocite law_3  \
# Timestamp
# 2020-04-01                   0.0                   0.39                  0.39
#
#             min_chalcocite law_3  rms_chalcocite law_3  var_chalcocite law_3  \
# Timestamp
# 2020-04-01                  0.39                  0.39          3.081488e-33
#
#             mean_covelin law_10  max_covelin law_10  min_covelin law_10  \
# Timestamp
# 2020-04-01                 0.03                0.03                0.03
#
#             rms_covelin law_10  var_covelin law_10  mean_covelin law_5  \
# Timestamp
# 2020-04-01                0.03        4.814825e-35                0.03
#
#             max_covelin law_5  min_covelin law_5  rms_covelin law_5  \
# Timestamp
# 2020-04-01               0.03               0.03               0.03
#
#             var_covelin law_5  mean_covelin law_3  max_covelin law_3  \
# Timestamp
# 2020-04-01                0.0                0.03               0.03
#
#             min_covelin law_3  rms_covelin law_3  var_covelin law_3  \
# Timestamp
# 2020-04-01               0.03               0.03                0.0
#
#             mean_crusher index_10  max_crusher index_10  min_crusher index_10  \
# Timestamp
# 2020-04-01                   19.4                  19.4                  19.4
#
#             rms_crusher index_10  var_crusher index_10  mean_crusher index_5  \
# Timestamp
# 2020-04-01                  19.4                   0.0                  19.4
#
#             max_crusher index_5  min_crusher index_5  rms_crusher index_5  \
# Timestamp
# 2020-04-01                 19.4                 19.4                 19.4
#
#             var_crusher index_5  mean_crusher index_3  max_crusher index_3  \
# Timestamp
# 2020-04-01                  0.0                  19.4                 19.4
#
#             min_crusher index_3  rms_crusher index_3  var_crusher index_3  \
# Timestamp
# 2020-04-01                 19.4                 19.4                  0.0
#
#             mean_ball work index_10  max_ball work index_10  \
# Timestamp
# 2020-04-01                     17.0                    17.0
#
#             min_ball work index_10  rms_ball work index_10  \
# Timestamp
# 2020-04-01                    17.0                    17.0
#
#             var_ball work index_10  mean_ball work index_5  \
# Timestamp
# 2020-04-01                     0.0                    17.0
#
#             max_ball work index_5  min_ball work index_5  \
# Timestamp
# 2020-04-01                   17.0                   17.0
#
#             rms_ball work index_5  var_ball work index_5  \
# Timestamp
# 2020-04-01                   17.0                    0.0
#
#             mean_ball work index_3  max_ball work index_3  \
# Timestamp
# 2020-04-01                    17.0                   17.0
#
#             min_ball work index_3  rms_ball work index_3  \
# Timestamp
# 2020-04-01                   17.0                   17.0
#
#             var_ball work index_3  mean_bornite law_10  max_bornite law_10  \
# Timestamp
# 2020-04-01                    0.0                 0.02                0.02
#
#             min_bornite law_10  rms_bornite law_10  var_bornite law_10  \
# Timestamp
# 2020-04-01                0.02                0.02        1.203706e-35
#
#             mean_bornite law_5  max_bornite law_5  min_bornite law_5  \
# Timestamp
# 2020-04-01                0.02               0.02               0.02
#
#             rms_bornite law_5  var_bornite law_5  mean_bornite law_3  \
# Timestamp
# 2020-04-01               0.02                0.0                0.02
#
#             max_bornite law_3  min_bornite law_3  rms_bornite law_3  \
# Timestamp
# 2020-04-01               0.02               0.02               0.02
#
#             var_bornite law_3  mean_charge cell_10  max_charge cell_10  \
# Timestamp
# 2020-04-01                0.0            770.33673          781.586053
#
#             min_charge cell_10  rms_charge cell_10  var_charge cell_10  \
# Timestamp
# 2020-04-01           755.74875          770.375245           59.340428
#
#             mean_charge cell_5  max_charge cell_5  min_charge cell_5  \
# Timestamp
# 2020-04-01          764.132392         770.226905          755.74875
#
#             rms_charge cell_5  var_charge cell_5  mean_charge cell_3  \
# Timestamp
# 2020-04-01         764.152383          30.552526          760.475969
#
#             max_charge cell_3  min_charge cell_3  rms_charge cell_3  \
# Timestamp
# 2020-04-01         765.858529          755.74875          760.48731
#
#             var_charge cell_3  mean_speed_10  max_speed_10  min_speed_10  \
# Timestamp
# 2020-04-01           17.24934       9.250187      9.251051      9.249285
#
#             rms_speed_10  var_speed_10  mean_speed_5  max_speed_5  \
# Timestamp
# 2020-04-01      9.250187  3.216375e-07      9.249989     9.250728
#
#             min_speed_5  rms_speed_5   var_speed_5  mean_speed_3  max_speed_3  \
# Timestamp
# 2020-04-01     9.249551     9.249989  1.541350e-07      9.250072     9.250728
#
#             min_speed_3  rms_speed_3   var_speed_3  mean_granulometry_10  \
# Timestamp
# 2020-04-01     9.249551     9.250072  2.399448e-07             29.546888
#
#             max_granulometry_10  min_granulometry_10  rms_granulometry_10  \
# Timestamp
# 2020-04-01            30.530144            28.344359            29.555798
#
#             var_granulometry_10  mean_granulometry_5  max_granulometry_5  \
# Timestamp
# 2020-04-01             0.526626            30.161736           30.530144
#
#             min_granulometry_5  rms_granulometry_5  var_granulometry_5  \
# Timestamp
# 2020-04-01           29.774353           30.163072            0.080616
#
#             mean_granulometry_3  max_granulometry_3  min_granulometry_3  \
# Timestamp
# 2020-04-01            30.368642           30.530144           30.163361
#
#             rms_granulometry_3  var_granulometry_3  mean_solid percentage_10  \
# Timestamp
# 2020-04-01           30.369027             0.02338                 64.999036
#
#             max_solid percentage_10  min_solid percentage_10  \
# Timestamp
# 2020-04-01                65.144943                64.831312
#
#             rms_solid percentage_10  var_solid percentage_10  \
# Timestamp
# 2020-04-01                64.999106                 0.008984
#
#             mean_solid percentage_5  max_solid percentage_5  \
# Timestamp
# 2020-04-01                65.010818               65.144943
#
#             min_solid percentage_5  rms_solid percentage_5  \
# Timestamp
# 2020-04-01               64.831312               65.010916
#
#             var_solid percentage_5  mean_solid percentage_3  \
# Timestamp
# 2020-04-01                  0.0128                 64.93533
#
#             max_solid percentage_3  min_solid percentage_3  \
# Timestamp
# 2020-04-01                65.03294               64.831312
#
#             rms_solid percentage_3  var_solid percentage_3  \
# Timestamp
# 2020-04-01               64.935382                0.006796
#
#             mean_HH charge cell_10  max_HH charge cell_10  \
# Timestamp
# 2020-04-01                   840.0                  840.0
#
#             min_HH charge cell_10  rms_HH charge cell_10  \
# Timestamp
# 2020-04-01                  840.0                  840.0
#
#             var_HH charge cell_10  mean_HH charge cell_5  \
# Timestamp
# 2020-04-01                    0.0                  840.0
#
#             max_HH charge cell_5  min_HH charge cell_5  rms_HH charge cell_5  \
# Timestamp
# 2020-04-01                 840.0                 840.0                 840.0
#
#             var_HH charge cell_5  mean_HH charge cell_3  max_HH charge cell_3  \
# Timestamp
# 2020-04-01                   0.0                  840.0                 840.0
#
#             min_HH charge cell_3  rms_HH charge cell_3  var_HH charge cell_3  \
# Timestamp
# 2020-04-01                 840.0                 840.0                   0.0
#
#             mean_LL charge cell_10  max_LL charge cell_10  \
# Timestamp
# 2020-04-01                   760.0                  760.0
#
#             min_LL charge cell_10  rms_LL charge cell_10  \
# Timestamp
# 2020-04-01                  760.0                  760.0
#
#             var_LL charge cell_10  mean_LL charge cell_5  \
# Timestamp
# 2020-04-01                    0.0                  760.0
#
#             max_LL charge cell_5  min_LL charge cell_5  rms_LL charge cell_5  \
# Timestamp
# 2020-04-01                 760.0                 760.0                 760.0
#
#             var_LL charge cell_5  mean_LL charge cell_3  max_LL charge cell_3  \
# Timestamp
# 2020-04-01                   0.0                  760.0                 760.0
#
#             min_LL charge cell_3  rms_LL charge cell_3  var_LL charge cell_3  \
# Timestamp
# 2020-04-01                 760.0                 760.0                   0.0
#
#             mean_delta HH charge cell_10  max_delta HH charge cell_10  \
# Timestamp
# 2020-04-01                      69.66327                     84.25125
#
#             min_delta HH charge cell_10  rms_delta HH charge cell_10  \
# Timestamp
# 2020-04-01                    58.413947                    70.087885
#
#             var_delta HH charge cell_10  mean_delta HH charge cell_5  \
# Timestamp
# 2020-04-01                    59.340428                    75.867608
#
#             max_delta HH charge cell_5  min_delta HH charge cell_5  \
# Timestamp
# 2020-04-01                    84.25125                   69.773095
#
#             rms_delta HH charge cell_5  var_delta HH charge cell_5  \
# Timestamp
# 2020-04-01                   76.068696                   30.552526
#
#             mean_delta HH charge cell_3  max_delta HH charge cell_3  \
# Timestamp
# 2020-04-01                    79.524031                    84.25125
#
#             min_delta HH charge cell_3  rms_delta HH charge cell_3  \
# Timestamp
# 2020-04-01                   74.141471                   79.632411
#
#             var_delta HH charge cell_3  mean_delta LL charge cell_10  \
# Timestamp
# 2020-04-01                    17.24934                      10.33673
#
#             max_delta LL charge cell_10  min_delta LL charge cell_10  \
# Timestamp
# 2020-04-01                    21.586053                     -4.25125
#
#             rms_delta LL charge cell_10  var_delta LL charge cell_10  \
# Timestamp
# 2020-04-01                    12.891409                    59.340428
#
#             mean_delta LL charge cell_5  max_delta LL charge cell_5  \
# Timestamp
# 2020-04-01                     4.132392                   10.226905
#
#             min_delta LL charge cell_5  rms_delta LL charge cell_5  \
# Timestamp
# 2020-04-01                    -4.25125                     6.90139
#
#             var_delta LL charge cell_5  mean_delta LL charge cell_3  \
# Timestamp
# 2020-04-01                   30.552526                     0.475969
#
#             max_delta LL charge cell_3  min_delta LL charge cell_3  \
# Timestamp
# 2020-04-01                    5.858529                    -4.25125
#
#             rms_delta LL charge cell_3  var_delta LL charge cell_3  \
# Timestamp
# 2020-04-01                    4.180417                    17.24934
#
#             pyrite law_(t-1)  pyrite law_(t-2)  pyrite law_(t-3)  \
# Timestamp
# 2020-04-01              3.14              3.14              3.14
#
#             pyrite law_(t-4)  pyrite law_(t-5)  chalcopyrite law_(t-1)  \
# Timestamp
# 2020-04-01              3.14              3.14                     1.6
#
#             chalcopyrite law_(t-2)  chalcopyrite law_(t-3)  \
# Timestamp
# 2020-04-01                     1.6                     1.6
#
#             chalcopyrite law_(t-4)  chalcopyrite law_(t-5)  \
# Timestamp
# 2020-04-01                     1.6                     1.6
#
#             chalcocite law_(t-1)  chalcocite law_(t-2)  chalcocite law_(t-3)  \
# Timestamp
# 2020-04-01                  0.39                  0.39                  0.39
#
#             chalcocite law_(t-4)  chalcocite law_(t-5)  covelin law_(t-1)  \
# Timestamp
# 2020-04-01                  0.39                  0.39               0.03
#
#             covelin law_(t-2)  covelin law_(t-3)  covelin law_(t-4)  \
# Timestamp
# 2020-04-01               0.03               0.03               0.03
#
#             covelin law_(t-5)  crusher index_(t-1)  crusher index_(t-2)  \
# Timestamp
# 2020-04-01               0.03                 19.4                 19.4
#
#             crusher index_(t-3)  crusher index_(t-4)  crusher index_(t-5)  \
# Timestamp
# 2020-04-01                 19.4                 19.4                 19.4
#
#             ball work index_(t-1)  ball work index_(t-2)  \
# Timestamp
# 2020-04-01                   17.0                   17.0
#
#             ball work index_(t-3)  ball work index_(t-4)  \
# Timestamp
# 2020-04-01                   17.0                   17.0
#
#             ball work index_(t-5)  bornite law_(t-1)  bornite law_(t-2)  \
# Timestamp
# 2020-04-01                   17.0               0.02               0.02
#
#             bornite law_(t-3)  bornite law_(t-4)  bornite law_(t-5)  \
# Timestamp
# 2020-04-01               0.02               0.02               0.02
#
#             charge cell_(t-1)  charge cell_(t-2)  charge cell_(t-3)  \
# Timestamp
# 2020-04-01         759.820628         765.858529         769.007146
#
#             charge cell_(t-4)  charge cell_(t-5)  speed_(t-1)  speed_(t-2)  \
# Timestamp
# 2020-04-01         770.226905         772.701618     9.250728     9.249937
#
#             speed_(t-3)  speed_(t-4)  speed_(t-5)  granulometry_(t-1)  \
# Timestamp
# 2020-04-01     9.249869     9.249862     9.250653           30.412421
#
#             granulometry_(t-2)  granulometry_(t-3)  granulometry_(t-4)  \
# Timestamp
# 2020-04-01           30.163361             29.9284           29.774353
#
#             granulometry_(t-5)  solid percentage_(t-1)  \
# Timestamp
# 2020-04-01           29.602554               64.831312
#
#             solid percentage_(t-2)  solid percentage_(t-3)  \
# Timestamp
# 2020-04-01               64.941738               65.103156
#
#             solid percentage_(t-4)  solid percentage_(t-5)  \
# Timestamp
# 2020-04-01               65.144943               65.033395
#
#             HH charge cell_(t-1)  HH charge cell_(t-2)  HH charge cell_(t-3)  \
# Timestamp
# 2020-04-01                 840.0                 840.0                 840.0
#
#             HH charge cell_(t-4)  HH charge cell_(t-5)  LL charge cell_(t-1)  \
# Timestamp
# 2020-04-01                 840.0                 840.0                 760.0
#
#             LL charge cell_(t-2)  LL charge cell_(t-3)  LL charge cell_(t-4)  \
# Timestamp
# 2020-04-01                 760.0                 760.0                 760.0
#
#             LL charge cell_(t-5)  delta HH charge cell_(t-1)  \
# Timestamp
# 2020-04-01                 760.0                   80.179372
#
#             delta HH charge cell_(t-2)  delta HH charge cell_(t-3)  \
# Timestamp
# 2020-04-01                   74.141471                   70.992854
#
#             delta HH charge cell_(t-4)  delta HH charge cell_(t-5)  \
# Timestamp
# 2020-04-01                   69.773095                   67.298382
#
#             delta LL charge cell_(t-1)  delta LL charge cell_(t-2)  \
# Timestamp
# 2020-04-01                   -0.179372                    5.858529
#
#             delta LL charge cell_(t-3)  delta LL charge cell_(t-4)  \
# Timestamp
# 2020-04-01                    9.007146                   10.226905
#
#             delta LL charge cell_(t-5)
# Timestamp
# 2020-04-01                   12.701618

# %%
tags=df_features.columns.to_list()
tags.remove("loss of TPH")
#tags.remove("TPH")

# %%
# Sobremuestreo: Aumentar numero de datos de la clase minoritaria
# ROS(Duplica clases):
ros=RandomOverSampler(random_state=0) # Random_state=0

# ROS:
Xtrain, Ytrain=ros.fit_resample(entrenamiento[tags],entrenamiento["loss of TPH"])

# %%
# Ytrain reg
#Ytrain=Xtrain["loss of TPH"]
Xtrain=Xtrain.drop(columns=["TPH"])

# %%
# Yval reg
Yval=validacion["loss of TPH"]
Xval=validacion.drop(columns=["loss of TPH","TPH"])

# %%
# Ytest reg
Ytest=test["loss of TPH"]
Xtest=test.drop(columns=["loss of TPH","TPH"])

# %%
#Unión del conjunto de Entrenamiento y Validación:
Entre_Vali_features=pd.concat([Xval,Xtrain])
Entre_Vali_target=pd.concat([Yval,Ytrain])

#Indices para separar ambos conjuntos:
Entre_indice=np.full(len(validacion),-1)
Vali_indice=np.full(len(entrenamiento),0)
Indices=np.append(Entre_indice,Vali_indice)
x=PredefinedSplit(Indices)

# %%
Color_loss=test["loss of TPH"]
Color_loss=Color_loss.astype(str)

# %% [markdown]
# # Feature selection

# %%
# Preprocesamiento de datos

preprocessing_transformer = ColumnTransformer(
    transformers=[
        ('MinMax', MinMaxScaler(),
        Xtrain.columns.to_list()
        ),
    ])

pipe = Pipeline(
    [
        ("preprocesamiento", preprocessing_transformer), 
     ("clf", xgb.XGBClassifier(seed=1,  eval_metric='mlogloss'))
    ]
)

# %%
pipe.fit(Xtrain, Ytrain)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('MinMax', MinMaxScaler(),
#                                                   ['sag power index',
#                                                    'mean_sag power index_10',
#                                                    'max_sag power index_10',
#                                                    'min_sag power index_10',
#                                                    'rms_sag power index_10',
#                                                    'var_sag power index_10',
#                                                    'mean_sag power index_5',
#                                                    'max_sag power index_5',
#                                                    'min_sag power index_5',
#                                                    'rms_sag power index_5',
#                                                    'var_sag power index_5',
#                                                    'mean_sag powe...
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1, predictor='auto',
#                                random_state=1, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=1, seed=1, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %% [markdown]
# **General**

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest)
print(classification_report(Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.80      0.86     94376
#          1.0       0.64      0.84      0.73     39276
#
#     accuracy                           0.81    133652
#    macro avg       0.78      0.82      0.79    133652
# weighted avg       0.84      0.81      0.82    133652

# %% [markdown]
# **2020**

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest["2020"])
print(classification_report(Ytest["2020"],Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.64      0.75     19501
#          1.0       0.70      0.93      0.80     17936
#
#     accuracy                           0.78     37437
#    macro avg       0.81      0.79      0.78     37437
# weighted avg       0.81      0.78      0.78     37437

# %% [markdown]
# **2021**

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest["2021"])
print(classification_report(Ytest["2021"],Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.91      0.93     28910
#          1.0       0.71      0.81      0.76      7691
#
#     accuracy                           0.89     36601
#    macro avg       0.83      0.86      0.84     36601
# weighted avg       0.90      0.89      0.89     36601

# %% [markdown]
# **2022**

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest["2022-01"])
print(classification_report(Ytest["2022-01"],Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.82      0.86     27412
#          1.0       0.50      0.70      0.59      7086
#
#     accuracy                           0.80     34498
#    macro avg       0.71      0.76      0.73     34498
# weighted avg       0.83      0.80      0.81     34498

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest["2022-02"])
print(classification_report(Ytest["2022-02"],Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.78      0.84     18553
#          1.0       0.55      0.79      0.65      6563
#
#     accuracy                           0.78     25116
#    macro avg       0.73      0.78      0.74     25116
# weighted avg       0.82      0.78      0.79     25116

# %%
df_importance=pd.DataFrame({"tag":Xtrain.columns,"importance":pipe["clf"].feature_importances_}).sort_values(by="importance",ascending=False).reset_index(drop=True)
df_importance.head()
# Out:
#                            tag  importance
# 0       min_solid percentage_5    0.120459
# 1             solid percentage    0.096574
# 2       min_solid percentage_3    0.088662
# 3   rms_delta LL charge cell_3    0.024193
# 4  min_delta LL charge cell_10    0.017377

# %%
pd.options.plotting.backend = "plotly"
fig=df_importance["importance"].plot(kind='hist')
fig.update_layout(height=500, width=1200,title="Feature importance XGBoost (Gain)",) 
fig.show()

# %%
# Plot
fig = go.Figure([go.Bar(x=df_importance["tag"], y=df_importance["importance"])])
fig.update_layout(height=500, width=1200,title="Feature importance XGBoost (Gain)",) 
fig.show()

# %%
xgboost_fs=df_importance[:100].tag.to_list()
xgboost_fs
# Out:
# ['min_solid percentage_5',
#  'solid percentage',
#  'min_solid percentage_3',
#  'rms_delta LL charge cell_3',
#  'min_delta LL charge cell_10',
#  'var_delta LL charge cell_3',
#  'var_delta HH charge cell_10',
#  'var_delta HH charge cell_3',
#  'min_speed_10',
#  'var_delta LL charge cell_10',
#  'mean_LL charge cell_10',
#  'rms_crusher index_5',
#  'max_delta LL charge cell_10',
#  'min_solid percentage_10',
#  'max_LL charge cell_5',
#  'max_covelin law_5',
#  'LL charge cell',
#  'ball work index_(t-1)',
#  'mean_chalcocite law_5',
#  'min_pyrite law_3',
#  'var_solid percentage_10',
#  'rms_speed_5',
#  'rms_delta LL charge cell_10',
#  'HH charge cell_(t-2)',
#  'rms_sag power index_10',
#  'var_solid percentage_5',
#  'min_speed_3',
#  'rms_chalcocite law_5',
#  'var_charge cell_10',
#  'delta LL charge cell',
#  'HH charge cell_(t-5)',
#  'chalcopyrite law_(t-2)',
#  'rms_LL charge cell_10',
#  'mean_pyrite law_5',
#  'rms_HH charge cell_10',
#  'min_delta HH charge cell_10',
#  'speed',
#  'HH charge cell_(t-3)',
#  'min_bornite law_5',
#  'min_sag power index_5',
#  'rms_HH charge cell_3',
#  'max_chalcocite law_5',
#  'mean_sag power index_3',
#  'HH TPH',
#  'mean_HH charge cell_5',
#  'bornite law_(t-5)',
#  'min_HH charge cell_10',
#  'mean_covelin law_3',
#  'min_LL charge cell_10',
#  'min_crusher index_5',
#  'mean_solid percentage_3',
#  'max_HH charge cell_10',
#  'rms_speed_3',
#  'min_ball work index_3',
#  'mean_pyrite law_3',
#  'rms_bornite law_10',
#  'crusher index_(t-3)',
#  'min_pyrite law_5',
#  'min_sag power index_3',
#  'rms_crusher index_10',
#  'covelin law_(t-3)',
#  'chalcocite law_(t-4)',
#  'min_crusher index_3',
#  'sag power index_(t-1)',
#  'max_ball work index_10',
#  'max_sag power index_5',
#  'crusher index_(t-1)',
#  'min_chalcocite law_5',
#  'min_chalcocite law_10',
#  'var_LL charge cell_10',
#  'max_sag power index_10',
#  'max_ball work index_3',
#  'delta HH charge cell',
#  'rms_delta HH charge cell_3',
#  'covelin law_(t-4)',
#  'Edad',
#  'min_ball work index_10',
#  'chalcocite law',
#  'mean_ball work index_5',
#  'max_covelin law_10',
#  'chalcopyrite law_(t-1)',
#  'var_speed_10',
#  'rms_chalcocite law_10',
#  'mean_HH charge cell_10',
#  'min_speed_5',
#  'crusher index_(t-2)',
#  'max_chalcopyrite law_3',
#  'var_covelin law_3',
#  'chalcocite law_(t-5)',
#  'min_bornite law_3',
#  'max_speed_10',
#  'min_covelin law_10',
#  'max_pyrite law_5',
#  'HH charge cell_(t-4)',
#  'HH charge cell',
#  'max_speed_3',
#  'charge cell_(t-3)',
#  'max_pyrite law_10',
#  'max_ball work index_5',
#  'pyrite law_(t-4)']

# %%
# Se obtienen tags altamente correlacionados y matriz que permite visualizar cuales son los par de tags altamente correlacionados
collinearity, table_cor=corrkill(Xtrain,xgboost_fs,corr_cut=0.9)

# %%
# Tags altamente correlacionados
table_cor
# Out:
#                             Feat1                        Feat2       Val
# 3483        rms_HH charge cell_10       mean_HH charge cell_10  0.999999
# 1032       mean_LL charge cell_10        rms_LL charge cell_10  0.999999
# 1083       mean_LL charge cell_10       mean_HH charge cell_10  0.999996
# 3234        rms_LL charge cell_10        rms_HH charge cell_10  0.999996
# 1694               LL charge cell               HH charge cell  0.999995
# ...                           ...                          ...       ...
# 3572  min_delta HH charge cell_10         delta HH charge cell  0.910151
# 1229  max_delta LL charge cell_10         delta LL charge cell  0.910140
# 1272  max_delta LL charge cell_10         delta HH charge cell  0.910137
# 2935         delta LL charge cell  min_delta HH charge cell_10  0.910128
# 473   min_delta LL charge cell_10   rms_delta HH charge cell_3  0.909068
#
# [317 rows x 3 columns]

# %%
tag_select = [i for i in xgboost_fs if i not in collinearity]
tag_select
# Out:
# ['min_solid percentage_5',
#  'rms_delta LL charge cell_3',
#  'min_delta LL charge cell_10',
#  'var_delta LL charge cell_3',
#  'var_delta HH charge cell_10',
#  'min_speed_10',
#  'mean_LL charge cell_10',
#  'rms_crusher index_5',
#  'max_delta LL charge cell_10',
#  'max_covelin law_5',
#  'ball work index_(t-1)',
#  'mean_chalcocite law_5',
#  'min_pyrite law_3',
#  'var_solid percentage_10',
#  'rms_sag power index_10',
#  'var_solid percentage_5',
#  'chalcopyrite law_(t-2)',
#  'min_bornite law_5',
#  'HH TPH',
#  'var_LL charge cell_10',
#  'Edad',
#  'var_speed_10',
#  'var_covelin law_3',
#  'charge cell_(t-3)']

# %%
# Preprocesamiento de datos

preprocessing_transformer = ColumnTransformer(
    transformers=[
        ('MinMax', MinMaxScaler(),
        tag_select
        ),
    ])

pipe = Pipeline(
    [
        ("preprocesamiento", preprocessing_transformer), 
     ("clf", xgb.XGBClassifier(seed=1,  eval_metric='mlogloss'))
    ]
)

# %%
pipe.fit(Xtrain, Ytrain)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('MinMax', MinMaxScaler(),
#                                                   ['min_solid percentage_5',
#                                                    'rms_delta LL charge cell_3',
#                                                    'min_delta LL charge '
#                                                    'cell_10',
#                                                    'var_delta LL charge cell_3',
#                                                    'var_delta HH charge '
#                                                    'cell_10',
#                                                    'min_speed_10',
#                                                    'mean_LL charge cell_10',
#                                                    'rms_crusher index_5',
#                                                    'max_delta LL charge '
#                                                    'cell_10',
#                                                    'max_covelin law_5',
#                                                    'ball work index_...
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1, predictor='auto',
#                                random_state=1, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=1, seed=1, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %% [markdown]
# **General**

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest)
print(classification_report(Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.82      0.87     94376
#          1.0       0.65      0.83      0.73     39276
#
#     accuracy                           0.82    133652
#    macro avg       0.79      0.82      0.80    133652
# weighted avg       0.84      0.82      0.83    133652

# %% [markdown]
# # GridSearch

# %%
# Preprocesamiento de datos

preprocessing_transformer = ColumnTransformer(
    transformers=[
        ('MinMax', MinMaxScaler(),
        tag_select
        #features.columns.to_list()
        ),
    ])

pipe = Pipeline(
    [
        ("preprocesamiento", preprocessing_transformer), 
        #("Selection", SelectPercentile(f_classif, percentile=10)),
        #("PCA",PCA(n_components=150 )), #0.08
     ("reg",  xgb.XGBClassifier(seed=1,  eval_metric='mlogloss'))
    ]
)


param_grid_reg = {'reg__learning_rate': list(np.linspace(0.001,1,10)), # Boosting learning rate
                  'reg__gamma':list(np.linspace(0.0001,50,5)), # Minimum loss reduction required to make a further partition on a leaf node of the tree.
                  #'reg__max_depth':[5,10,12,15,20], # Maximum tree depth for base learners.
                  #'reg__min_child_weight':[10,5,1,2,3], # Minimum sum of instance weight(hessian) needed in a child.
                  #'reg__colsample_bytree':[0.5,0.8,1], # Subsample ratio of columns when constructing each tree.
                  'reg__n_estimators': [100,200,300], # Number of gradient boosted trees.   
                  #'reg__reg_alpha': [0,0.1,0.2,0.4,0.8,1.6,3.2,6.4,12.8,25.6,51.2,102.4,200],
              #'reg__reg_lambda': [0,0.1,0.2,0.4,0.8,1.6,3.2,6.4,12.8,25.6,51.2,102.4,200],
               #'Selection__percentile': [10,20,30,50,70,80,100]              
                 } 

# Clasificación
gs_reg = HalvingGridSearchCV(pipe, param_grid_reg, scoring='neg_mean_absolute_error',cv=x,refit=True,
                             verbose=10,
                             aggressive_elimination=True
                            )

# Fit
gs_reg.fit(Entre_Vali_features, Entre_Vali_target)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 12282
# max_resources_: 994906
# aggressive_elimination: True
# factor: 3
# ----------
# iter: 0
# n_candidates: 150
# n_resources: 12282
# Fitting 1 folds for each of 150 candidates, totalling 150 fits
# [CV 1/1; 1/150] START reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=100
# [CV 1/1; 1/150] END reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=100;, score=(train=-0.073, test=-0.189) total time=   9.1s
# [CV 1/1; 2/150] START reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=200
# [CV 1/1; 2/150] END reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=200;, score=(train=-0.066, test=-0.184) total time=   0.5s
# [CV 1/1; 3/150] START reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=300
# [CV 1/1; 3/150] END reg__gamma=0.0001, reg__learning_rate=0.001, reg__n_estimators=300;, score=(train=-0.063, test=-0.180) total time=   0.7s
# [CV 1/1; 4/150] START reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 4/150] END reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.001, test=-0.172) total time=   0.2s
# [CV 1/1; 5/150] START reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 5/150] END reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.000, test=-0.175) total time=   0.4s
# [CV 1/1; 6/150] START reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 6/150] END reg__gamma=0.0001, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.000, test=-0.174) total time=   0.4s
# [CV 1/1; 7/150] START reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 7/150] END reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.000, test=-0.172) total time=   0.2s
# [CV 1/1; 8/150] START reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 8/150] END reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.000, test=-0.175) total time=   0.3s
# [CV 1/1; 9/150] START reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 9/150] END reg__gamma=0.0001, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.000, test=-0.173) total time=   0.3s
# [CV 1/1; 10/150] START reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 10/150] END reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.000, test=-0.175) total time=   0.1s
# [CV 1/1; 11/150] START reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 11/150] END reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.000, test=-0.177) total time=   0.2s
# [CV 1/1; 12/150] START reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 12/150] END reg__gamma=0.0001, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.000, test=-0.178) total time=   0.3s
# [CV 1/1; 13/150] START reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 13/150] END reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.000, test=-0.182) total time=   0.1s
# [CV 1/1; 14/150] START reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 14/150] END reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.000, test=-0.183) total time=   0.2s
# [CV 1/1; 15/150] START reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 15/150] END reg__gamma=0.0001, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.000, test=-0.183) total time=   0.3s
# [CV 1/1; 16/150] START reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 16/150] END reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.000, test=-0.184) total time=   0.1s
# [CV 1/1; 17/150] START reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 17/150] END reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.000, test=-0.185) total time=   0.2s
# [CV 1/1; 18/150] START reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 18/150] END reg__gamma=0.0001, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.000, test=-0.185) total time=   0.3s
# [CV 1/1; 19/150] START reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 19/150] END reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.000, test=-0.196) total time=   0.1s
# [CV 1/1; 20/150] START reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 20/150] END reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.000, test=-0.196) total time=   0.2s
# [CV 1/1; 21/150] START reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 21/150] END reg__gamma=0.0001, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.000, test=-0.197) total time=   0.3s
# [CV 1/1; 22/150] START reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 22/150] END reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.000, test=-0.181) total time=   0.1s
# [CV 1/1; 23/150] START reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 23/150] END reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.000, test=-0.181) total time=   0.2s
# [CV 1/1; 24/150] START reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 24/150] END reg__gamma=0.0001, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.000, test=-0.183) total time=   0.3s
# [CV 1/1; 25/150] START reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 25/150] END reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.000, test=-0.183) total time=   0.1s
# [CV 1/1; 26/150] START reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 26/150] END reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.000, test=-0.183) total time=   0.2s
# [CV 1/1; 27/150] START reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 27/150] END reg__gamma=0.0001, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.000, test=-0.183) total time=   0.3s
# [CV 1/1; 28/150] START reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 28/150] END reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.000, test=-0.194) total time=   0.1s
# [CV 1/1; 29/150] START reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 29/150] END reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.000, test=-0.198) total time=   0.2s
# [CV 1/1; 30/150] START reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 30/150] END reg__gamma=0.0001, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.000, test=-0.198) total time=   0.3s
# [CV 1/1; 31/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=100
# [CV 1/1; 31/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=100;, score=(train=-0.123, test=-0.158) total time=   0.2s
# [CV 1/1; 32/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=200
# [CV 1/1; 32/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=200;, score=(train=-0.125, test=-0.158) total time=   0.4s
# [CV 1/1; 33/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=300
# [CV 1/1; 33/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.001, reg__n_estimators=300;, score=(train=-0.126, test=-0.157) total time=   0.6s
# [CV 1/1; 34/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 34/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.117, test=-0.150) total time=   0.2s
# [CV 1/1; 35/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 35/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.117, test=-0.150) total time=   0.4s
# [CV 1/1; 36/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 36/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.117, test=-0.150) total time=   0.6s
# [CV 1/1; 37/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 37/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.115, test=-0.157) total time=   0.2s
# [CV 1/1; 38/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 38/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.115, test=-0.157) total time=   0.3s
# [CV 1/1; 39/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 39/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.115, test=-0.157) total time=   0.5s
# [CV 1/1; 40/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 40/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.115, test=-0.153) total time=   0.2s
# [CV 1/1; 41/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 41/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.115, test=-0.153) total time=   0.4s
# [CV 1/1; 42/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 42/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.115, test=-0.153) total time=   0.6s
# [CV 1/1; 43/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 43/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.115, test=-0.155) total time=   0.2s
# [CV 1/1; 44/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 44/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.115, test=-0.155) total time=   0.4s
# [CV 1/1; 45/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 45/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.115, test=-0.155) total time=   0.5s
# [CV 1/1; 46/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 46/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.116, test=-0.156) total time=   0.2s
# [CV 1/1; 47/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 47/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.116, test=-0.156) total time=   0.3s
# [CV 1/1; 48/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 48/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.116, test=-0.156) total time=   0.5s
# [CV 1/1; 49/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 49/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.121, test=-0.158) total time=   0.2s
# [CV 1/1; 50/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 50/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.121, test=-0.158) total time=   0.4s
# [CV 1/1; 51/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 51/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.121, test=-0.158) total time=   0.6s
# [CV 1/1; 52/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 52/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.126, test=-0.159) total time=   0.2s
# [CV 1/1; 53/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 53/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.126, test=-0.159) total time=   0.4s
# [CV 1/1; 54/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 54/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.126, test=-0.159) total time=   0.5s
# [CV 1/1; 55/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 55/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.118, test=-0.161) total time=   0.2s
# [CV 1/1; 56/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 56/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.118, test=-0.161) total time=   0.4s
# [CV 1/1; 57/150] START reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 57/150] END reg__gamma=12.500074999999999, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.118, test=-0.161) total time=   0.6s
# [CV 1/1; 58/150] START reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 58/150] END reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.123, test=-0.164) total time=   0.2s
# [CV 1/1; 59/150] START reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 59/150] END reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.123, test=-0.164) total time=   0.4s
# [CV 1/1; 60/150] START reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 60/150] END reg__gamma=12.500074999999999, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.123, test=-0.164) total time=   0.6s
# [CV 1/1; 61/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=100
# [CV 1/1; 61/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=100;, score=(train=-0.161, test=-0.160) total time=   0.2s
# [CV 1/1; 62/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=200
# [CV 1/1; 62/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=200;, score=(train=-0.161, test=-0.160) total time=   0.4s
# [CV 1/1; 63/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=300
# [CV 1/1; 63/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.001, reg__n_estimators=300;, score=(train=-0.148, test=-0.162) total time=   0.6s
# [CV 1/1; 64/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 64/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.145, test=-0.148) total time=   0.2s
# [CV 1/1; 65/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 65/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.145, test=-0.148) total time=   0.5s
# [CV 1/1; 66/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 66/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.145, test=-0.148) total time=   0.6s
# [CV 1/1; 67/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 67/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.143, test=-0.152) total time=   0.2s
# [CV 1/1; 68/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 68/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.143, test=-0.152) total time=   0.4s
# [CV 1/1; 69/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 69/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.143, test=-0.152) total time=   0.6s
# [CV 1/1; 70/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 70/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.151, test=-0.152) total time=   0.2s
# [CV 1/1; 71/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 71/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.151, test=-0.152) total time=   0.4s
# [CV 1/1; 72/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 72/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.151, test=-0.152) total time=   0.6s
# [CV 1/1; 73/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 73/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.158, test=-0.152) total time=   0.2s
# [CV 1/1; 74/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 74/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.158, test=-0.152) total time=   0.4s
# [CV 1/1; 75/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 75/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.158, test=-0.152) total time=   0.6s
# [CV 1/1; 76/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 76/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.155, test=-0.158) total time=   0.3s
# [CV 1/1; 77/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 77/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.155, test=-0.158) total time=   0.4s
# [CV 1/1; 78/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 78/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.155, test=-0.158) total time=   0.7s
# [CV 1/1; 79/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 79/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.155, test=-0.158) total time=   0.2s
# [CV 1/1; 80/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 80/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.155, test=-0.158) total time=   0.4s
# [CV 1/1; 81/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 81/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.155, test=-0.158) total time=   0.6s
# [CV 1/1; 82/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 82/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.147, test=-0.156) total time=   0.2s
# [CV 1/1; 83/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 83/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.147, test=-0.156) total time=   0.4s
# [CV 1/1; 84/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 84/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.147, test=-0.156) total time=   0.6s
# [CV 1/1; 85/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 85/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.156, test=-0.185) total time=   0.2s
# [CV 1/1; 86/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 86/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.156, test=-0.185) total time=   0.4s
# [CV 1/1; 87/150] START reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 87/150] END reg__gamma=25.000049999999998, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.156, test=-0.185) total time=   0.6s
# [CV 1/1; 88/150] START reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 88/150] END reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.156, test=-0.185) total time=   0.2s
# [CV 1/1; 89/150] START reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 89/150] END reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.156, test=-0.185) total time=   0.4s
# [CV 1/1; 90/150] START reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 90/150] END reg__gamma=25.000049999999998, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.156, test=-0.185) total time=   0.6s
# [CV 1/1; 91/150] START reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=100
# [CV 1/1; 91/150] END reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=100;, score=(train=-0.198, test=-0.166) total time=   0.2s
# [CV 1/1; 92/150] START reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=200
# [CV 1/1; 92/150] END reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=200;, score=(train=-0.209, test=-0.161) total time=   0.4s
# [CV 1/1; 93/150] START reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=300
# [CV 1/1; 93/150] END reg__gamma=37.500025, reg__learning_rate=0.001, reg__n_estimators=300;, score=(train=-0.205, test=-0.162) total time=   0.6s
# [CV 1/1; 94/150] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 94/150] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.179, test=-0.154) total time=   0.2s
# [CV 1/1; 95/150] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 95/150] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.179, test=-0.154) total time=   0.4s
# [CV 1/1; 96/150] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 96/150] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.179, test=-0.154) total time=   0.6s
# [CV 1/1; 97/150] START reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 97/150] END reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.179, test=-0.156) total time=   0.2s
# [CV 1/1; 98/150] START reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 98/150] END reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.179, test=-0.156) total time=   0.4s
# [CV 1/1; 99/150] START reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 99/150] END reg__gamma=37.500025, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.179, test=-0.156) total time=   0.6s
# [CV 1/1; 100/150] START reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 100/150] END reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.166, test=-0.158) total time=   0.2s
# [CV 1/1; 101/150] START reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 101/150] END reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.166, test=-0.158) total time=   0.4s
# [CV 1/1; 102/150] START reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 102/150] END reg__gamma=37.500025, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.166, test=-0.158) total time=   0.7s
# [CV 1/1; 103/150] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 103/150] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.178, test=-0.151) total time=   0.2s
# [CV 1/1; 104/150] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 104/150] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.178, test=-0.151) total time=   0.4s
# [CV 1/1; 105/150] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 105/150] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.178, test=-0.151) total time=   0.6s
# [CV 1/1; 106/150] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 106/150] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.176, test=-0.148) total time=   0.2s
# [CV 1/1; 107/150] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 107/150] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.176, test=-0.148) total time=   0.4s
# [CV 1/1; 108/150] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 108/150] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.176, test=-0.148) total time=   0.6s
# [CV 1/1; 109/150] START reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 109/150] END reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.173, test=-0.155) total time=   0.2s
# [CV 1/1; 110/150] START reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 110/150] END reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.173, test=-0.155) total time=   0.5s
# [CV 1/1; 111/150] START reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 111/150] END reg__gamma=37.500025, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.173, test=-0.155) total time=   0.6s
# [CV 1/1; 112/150] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 112/150] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.172, test=-0.154) total time=   0.2s
# [CV 1/1; 113/150] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 113/150] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.172, test=-0.154) total time=   0.4s
# [CV 1/1; 114/150] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 114/150] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.172, test=-0.154) total time=   0.7s
# [CV 1/1; 115/150] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 115/150] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.166, test=-0.154) total time=   0.2s
# [CV 1/1; 116/150] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 116/150] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.166, test=-0.154) total time=   0.4s
# [CV 1/1; 117/150] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 117/150] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.166, test=-0.154) total time=   0.7s
# [CV 1/1; 118/150] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 118/150] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.166, test=-0.154) total time=   0.2s
# [CV 1/1; 119/150] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 119/150] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.166, test=-0.154) total time=   0.5s
# [CV 1/1; 120/150] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 120/150] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.166, test=-0.154) total time=   0.7s
# [CV 1/1; 121/150] START reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=100
# [CV 1/1; 121/150] END reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=100;, score=(train=-0.218, test=-0.164) total time=   0.2s
# [CV 1/1; 122/150] START reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=200
# [CV 1/1; 122/150] END reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=200;, score=(train=-0.215, test=-0.164) total time=   0.4s
# [CV 1/1; 123/150] START reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=300
# [CV 1/1; 123/150] END reg__gamma=50.0, reg__learning_rate=0.001, reg__n_estimators=300;, score=(train=-0.215, test=-0.163) total time=   0.6s
# [CV 1/1; 124/150] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 124/150] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.182, test=-0.154) total time=   0.2s
# [CV 1/1; 125/150] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 125/150] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.182, test=-0.154) total time=   0.5s
# [CV 1/1; 126/150] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 126/150] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.182, test=-0.154) total time=   0.6s
# [CV 1/1; 127/150] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 127/150] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.194, test=-0.153) total time=   0.2s
# [CV 1/1; 128/150] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 128/150] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.194, test=-0.153) total time=   0.4s
# [CV 1/1; 129/150] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 129/150] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.194, test=-0.153) total time=   0.6s
# [CV 1/1; 130/150] START reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 130/150] END reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.190, test=-0.158) total time=   0.2s
# [CV 1/1; 131/150] START reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 131/150] END reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.190, test=-0.158) total time=   0.4s
# [CV 1/1; 132/150] START reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 132/150] END reg__gamma=50.0, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.190, test=-0.158) total time=   0.7s
# [CV 1/1; 133/150] START reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 133/150] END reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.192, test=-0.155) total time=   0.3s
# [CV 1/1; 134/150] START reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 134/150] END reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.192, test=-0.155) total time=   0.4s
# [CV 1/1; 135/150] START reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 135/150] END reg__gamma=50.0, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.192, test=-0.155) total time=   0.6s
# [CV 1/1; 136/150] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 136/150] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.184, test=-0.151) total time=   0.2s
# [CV 1/1; 137/150] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 137/150] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.184, test=-0.151) total time=   0.4s
# [CV 1/1; 138/150] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 138/150] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.184, test=-0.151) total time=   0.6s
# [CV 1/1; 139/150] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 139/150] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.172, test=-0.154) total time=   0.3s
# [CV 1/1; 140/150] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 140/150] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.172, test=-0.154) total time=   0.4s
# [CV 1/1; 141/150] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 141/150] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.172, test=-0.154) total time=   0.7s
# [CV 1/1; 142/150] START reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 142/150] END reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.175, test=-0.156) total time=   0.2s
# [CV 1/1; 143/150] START reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 143/150] END reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.175, test=-0.156) total time=   0.5s
# [CV 1/1; 144/150] START reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 144/150] END reg__gamma=50.0, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.175, test=-0.156) total time=   0.6s
# [CV 1/1; 145/150] START reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 145/150] END reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.171, test=-0.157) total time=   0.2s
# [CV 1/1; 146/150] START reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 146/150] END reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.171, test=-0.157) total time=   0.4s
# [CV 1/1; 147/150] START reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 147/150] END reg__gamma=50.0, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.171, test=-0.157) total time=   0.6s
# [CV 1/1; 148/150] START reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 148/150] END reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.251, test=-0.201) total time=   0.2s
# [CV 1/1; 149/150] START reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 149/150] END reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.251, test=-0.201) total time=   0.4s
# [CV 1/1; 150/150] START reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 150/150] END reg__gamma=50.0, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.251, test=-0.201) total time=   0.6s
# ----------
# iter: 1
# n_candidates: 50
# n_resources: 36846
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1; 1/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 1/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.100, test=-0.151) total time=   0.8s
# [CV 1/1; 2/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 2/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.100, test=-0.151) total time=   1.0s
# [CV 1/1; 3/50] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 3/50] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.136, test=-0.139) total time=   0.7s
# [CV 1/1; 4/50] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 4/50] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.136, test=-0.139) total time=   1.4s
# [CV 1/1; 5/50] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 5/50] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.136, test=-0.139) total time=   1.0s
# [CV 1/1; 6/50] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=200
# [CV 1/1; 6/50] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=200;, score=(train=-0.153, test=-0.159) total time=   1.0s
# [CV 1/1; 7/50] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=300
# [CV 1/1; 7/50] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=300;, score=(train=-0.153, test=-0.159) total time=   1.4s
# [CV 1/1; 8/50] START reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=100
# [CV 1/1; 8/50] END reg__gamma=37.500025, reg__learning_rate=0.778, reg__n_estimators=100;, score=(train=-0.153, test=-0.159) total time=   0.6s
# [CV 1/1; 9/50] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=100
# [CV 1/1; 9/50] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=100;, score=(train=-0.159, test=-0.158) total time=   0.6s
# [CV 1/1; 10/50] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=200
# [CV 1/1; 10/50] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=200;, score=(train=-0.159, test=-0.158) total time=   1.0s
# [CV 1/1; 11/50] START reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=300
# [CV 1/1; 11/50] END reg__gamma=50.0, reg__learning_rate=0.667, reg__n_estimators=300;, score=(train=-0.159, test=-0.158) total time=   1.4s
# [CV 1/1; 12/50] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=100
# [CV 1/1; 12/50] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=100;, score=(train=-0.155, test=-0.156) total time=   0.6s
# [CV 1/1; 13/50] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 13/50] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.146, test=-0.141) total time=   0.6s
# [CV 1/1; 14/50] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=200
# [CV 1/1; 14/50] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=200;, score=(train=-0.155, test=-0.156) total time=   1.0s
# [CV 1/1; 15/50] START reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=300
# [CV 1/1; 15/50] END reg__gamma=37.500025, reg__learning_rate=1.0, reg__n_estimators=300;, score=(train=-0.155, test=-0.156) total time=   1.3s
# [CV 1/1; 16/50] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=300
# [CV 1/1; 16/50] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=300;, score=(train=-0.152, test=-0.170) total time=   1.5s
# [CV 1/1; 17/50] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 17/50] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.146, test=-0.141) total time=   1.4s
# [CV 1/1; 18/50] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=100
# [CV 1/1; 18/50] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=100;, score=(train=-0.152, test=-0.170) total time=   0.6s
# [CV 1/1; 19/50] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 19/50] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.146, test=-0.141) total time=   1.0s
# [CV 1/1; 20/50] START reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=200
# [CV 1/1; 20/50] END reg__gamma=37.500025, reg__learning_rate=0.889, reg__n_estimators=200;, score=(train=-0.152, test=-0.170) total time=   1.0s
# [CV 1/1; 21/50] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 21/50] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.145, test=-0.142) total time=   1.1s
# [CV 1/1; 22/50] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 22/50] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.145, test=-0.142) total time=   1.5s
# [CV 1/1; 23/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 23/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.099, test=-0.145) total time=   0.6s
# [CV 1/1; 24/50] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 24/50] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.145, test=-0.142) total time=   0.6s
# [CV 1/1; 25/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 25/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.099, test=-0.145) total time=   1.5s
# [CV 1/1; 26/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 26/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.099, test=-0.145) total time=   1.1s
# [CV 1/1; 27/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 27/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.118, test=-0.145) total time=   1.0s
# [CV 1/1; 28/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 28/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.118, test=-0.145) total time=   0.6s
# [CV 1/1; 29/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 29/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.118, test=-0.145) total time=   1.3s
# [CV 1/1; 30/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 30/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.124, test=-0.142) total time=   1.4s
# [CV 1/1; 31/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 31/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.124, test=-0.142) total time=   1.0s
# [CV 1/1; 32/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 32/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.124, test=-0.142) total time=   0.6s
# [CV 1/1; 33/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 33/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.122, test=-0.142) total time=   1.4s
# [CV 1/1; 34/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 34/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.122, test=-0.142) total time=   1.0s
# [CV 1/1; 35/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 35/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.122, test=-0.142) total time=   0.7s
# [CV 1/1; 36/50] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 36/50] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.157, test=-0.153) total time=   0.6s
# [CV 1/1; 37/50] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 37/50] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.157, test=-0.153) total time=   1.0s
# [CV 1/1; 38/50] START reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 38/50] END reg__gamma=50.0, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.157, test=-0.153) total time=   1.4s
# [CV 1/1; 39/50] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=100
# [CV 1/1; 39/50] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=100;, score=(train=-0.138, test=-0.145) total time=   0.7s
# [CV 1/1; 40/50] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=300
# [CV 1/1; 40/50] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=300;, score=(train=-0.138, test=-0.145) total time=   1.5s
# [CV 1/1; 41/50] START reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=200
# [CV 1/1; 41/50] END reg__gamma=37.500025, reg__learning_rate=0.445, reg__n_estimators=200;, score=(train=-0.138, test=-0.145) total time=   1.1s
# [CV 1/1; 42/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 42/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.098, test=-0.143) total time=   1.0s
# [CV 1/1; 43/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 43/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.098, test=-0.143) total time=   1.3s
# [CV 1/1; 44/50] START reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 44/50] END reg__gamma=12.500074999999999, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.098, test=-0.143) total time=   0.6s
# [CV 1/1; 45/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 45/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.122, test=-0.138) total time=   1.1s
# [CV 1/1; 46/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 46/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.122, test=-0.138) total time=   1.5s
# [CV 1/1; 47/50] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 47/50] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.122, test=-0.138) total time=   0.6s
# [CV 1/1; 48/50] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=300
# [CV 1/1; 48/50] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=300;, score=(train=-0.141, test=-0.145) total time=   1.4s
# [CV 1/1; 49/50] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=100
# [CV 1/1; 49/50] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=100;, score=(train=-0.141, test=-0.145) total time=   0.6s
# [CV 1/1; 50/50] START reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=200
# [CV 1/1; 50/50] END reg__gamma=37.500025, reg__learning_rate=0.556, reg__n_estimators=200;, score=(train=-0.141, test=-0.145) total time=   1.0s
# ----------
# iter: 2
# n_candidates: 17
# n_resources: 110538
# Fitting 1 folds for each of 17 candidates, totalling 17 fits
# [CV 1/1; 1/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 1/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.105, test=-0.154) total time=   2.6s
# [CV 1/1; 2/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 2/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.105, test=-0.154) total time=   1.6s
# [CV 1/1; 3/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100
# [CV 1/1; 3/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=100;, score=(train=-0.106, test=-0.154) total time=   1.6s
# [CV 1/1; 4/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200
# [CV 1/1; 4/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=200;, score=(train=-0.106, test=-0.154) total time=   2.6s
# [CV 1/1; 5/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300
# [CV 1/1; 5/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.334, reg__n_estimators=300;, score=(train=-0.106, test=-0.154) total time=   3.6s
# [CV 1/1; 6/17] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100
# [CV 1/1; 6/17] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=100;, score=(train=-0.121, test=-0.148) total time=   1.5s
# [CV 1/1; 7/17] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300
# [CV 1/1; 7/17] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=300;, score=(train=-0.121, test=-0.148) total time=   3.5s
# [CV 1/1; 8/17] START reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200
# [CV 1/1; 8/17] END reg__gamma=50.0, reg__learning_rate=0.223, reg__n_estimators=200;, score=(train=-0.121, test=-0.148) total time=   2.4s
# [CV 1/1; 9/17] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 9/17] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.123, test=-0.146) total time=   2.6s
# [CV 1/1; 10/17] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 10/17] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.123, test=-0.146) total time=   1.6s
# [CV 1/1; 11/17] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 11/17] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.123, test=-0.146) total time=   3.6s
# [CV 1/1; 12/17] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 12/17] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.115, test=-0.146) total time=   3.4s
# [CV 1/1; 13/17] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 13/17] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.115, test=-0.146) total time=   1.5s
# [CV 1/1; 14/17] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 14/17] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.115, test=-0.146) total time=   2.5s
# [CV 1/1; 15/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 15/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.105, test=-0.152) total time=   2.6s
# [CV 1/1; 16/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 16/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.105, test=-0.152) total time=   3.5s
# [CV 1/1; 17/17] START reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 17/17] END reg__gamma=25.000049999999998, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.105, test=-0.152) total time=   1.5s
# ----------
# iter: 3
# n_candidates: 6
# n_resources: 331614
# Fitting 1 folds for each of 6 candidates, totalling 6 fits
# [CV 1/1; 1/6] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 1/6] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.094, test=-0.166) total time=   9.4s
# [CV 1/1; 2/6] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 2/6] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.094, test=-0.166) total time=   4.3s
# [CV 1/1; 3/6] START reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 3/6] END reg__gamma=37.500025, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.094, test=-0.166) total time=   6.7s
# [CV 1/1; 4/6] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100
# [CV 1/1; 4/6] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=100;, score=(train=-0.103, test=-0.163) total time=   4.2s
# [CV 1/1; 5/6] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 5/6] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.103, test=-0.163) total time=   9.3s
# [CV 1/1; 6/6] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 6/6] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.103, test=-0.163) total time=   6.7s
# ----------
# iter: 4
# n_candidates: 2
# n_resources: 994842
# Fitting 1 folds for each of 2 candidates, totalling 2 fits
# [CV 1/1; 1/2] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300
# [CV 1/1; 1/2] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=300;, score=(train=-0.082, test=-0.170) total time=  28.6s
# [CV 1/1; 2/2] START reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200
# [CV 1/1; 2/2] END reg__gamma=50.0, reg__learning_rate=0.112, reg__n_estimators=200;, score=(train=-0.082, test=-0.170) total time=  21.3s
# HalvingGridSearchCV(aggressive_elimination=True,
#                     cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#                     estimator=Pipeline(steps=[('preprocesamiento',
#                                                ColumnTransformer(transformers=[('MinMax',
#                                                                                 MinMaxScaler(),
#                                                                                 ['min_solid '
#                                                                                  'percentage_5',
#                                                                                  'rms_delta '
#                                                                                  'LL '
#                                                                                  'charge '
#                                                                                  'cell_3',
#                                                                                  'min_delta '
#                                                                                  'LL '
#                                                                                  'charge '
#                                                                                  'cell_10',
#                                                                                  'var_delta '
#                                                                                  'LL '
#                                                                                  'charge '
#                                                                                  'cell_3',
#                                                                                  'var_delta '
#                                                                                  'HH '
#                                                                                  'charge...
#                                                              scale_pos_weight=None,
#                                                              seed=1,
#                                                              subsample=None,
#                                                              tree_method=None,
#                                                              validate_parameters=None,
#                                                              verbosity=None))]),
#                     param_grid={'reg__gamma': [0.0001, 12.500074999999999,
#                                                25.000049999999998, 37.500025,
#                                                50.0],
#                                 'reg__learning_rate': [0.001, 0.112, 0.223,
#                                                        0.334, 0.445, 0.556,
#                                                        0.667, 0.778, 0.889,
#                                                        1.0],
#                                 'reg__n_estimators': [100, 200, 300]},
#                     scoring='neg_mean_absolute_error', verbose=10)

# %%
gs_reg.best_params_
# Out:
# {'reg__gamma': 50.0, 'reg__learning_rate': 0.112, 'reg__n_estimators': 300}

# %%
# Métricas de evaluación 
Ypred= gs_reg.predict(Xtest)
print(classification_report(Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.81      0.87     94376
#          1.0       0.65      0.84      0.74     39276
#
#     accuracy                           0.82    133652
#    macro avg       0.79      0.83      0.80    133652
# weighted avg       0.85      0.82      0.83    133652

# %% [markdown]
# # Train model

# %%
tag_select
# Out:
# ['min_solid percentage_5',
#  'rms_delta LL charge cell_3',
#  'min_delta LL charge cell_10',
#  'var_delta LL charge cell_3',
#  'var_delta HH charge cell_10',
#  'min_speed_10',
#  'mean_LL charge cell_10',
#  'rms_crusher index_5',
#  'max_delta LL charge cell_10',
#  'max_covelin law_5',
#  'ball work index_(t-1)',
#  'mean_chalcocite law_5',
#  'min_pyrite law_3',
#  'var_solid percentage_10',
#  'rms_sag power index_10',
#  'var_solid percentage_5',
#  'chalcopyrite law_(t-2)',
#  'min_bornite law_5',
#  'HH TPH',
#  'var_LL charge cell_10',
#  'Edad',
#  'var_speed_10',
#  'var_covelin law_3',
#  'charge cell_(t-3)']

# %%
tag_select=['min_solid percentage_5',
 'rms_delta LL charge cell_3',
 'min_delta LL charge cell_10',
 'var_delta LL charge cell_3',
 'var_delta HH charge cell_10',
 'min_speed_10',
 'mean_LL charge cell_10',
 'rms_crusher index_5',
 'max_delta LL charge cell_10',
 'max_covelin law_5',
 'ball work index_(t-1)',
 'mean_chalcocite law_5',
 'min_pyrite law_3',
 'var_solid percentage_10',
 'rms_sag power index_10',
 'var_solid percentage_5',
 'chalcopyrite law_(t-2)',
 'min_bornite law_5',
 'HH TPH',
 'var_LL charge cell_10',
 'Edad',
 'var_speed_10',
 'var_covelin law_3',
 'charge cell_(t-3)']

# %%
gs_reg.best_params_
# Out:
# {'reg__gamma': 50.0, 'reg__learning_rate': 0.112, 'reg__n_estimators': 300}

# %%
# Preprocesamiento de datos

preprocessing_transformer = ColumnTransformer(
    transformers=[
        ('MinMax', MinMaxScaler(),
        tag_select
        ),
    ])

pipe = Pipeline(
    [
        ("preprocesamiento", preprocessing_transformer), 
     ("clf",   xgb.XGBClassifier(seed=1,  eval_metric='mlogloss',gamma= 50, learning_rate= 0.112, n_estimators= 300))
    ]
)
pipe.fit(Xtrain, Ytrain)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('MinMax', MinMaxScaler(),
#                                                   ['min_solid percentage_5',
#                                                    'rms_delta LL charge cell_3',
#                                                    'min_delta LL charge '
#                                                    'cell_10',
#                                                    'var_delta LL charge cell_3',
#                                                    'var_delta HH charge '
#                                                    'cell_10',
#                                                    'min_speed_10',
#                                                    'mean_LL charge cell_10',
#                                                    'rms_crusher index_5',
#                                                    'max_delta LL charge '
#                                                    'cell_10',
#                                                    'max_covelin law_5',
#                                                    'ball work index_...
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.112, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=300,
#                                n_jobs=8, num_parallel_tree=1, predictor='auto',
#                                random_state=1, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=1, seed=1, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %% [markdown]
# **General**

# %%
Ytest.value_counts()
# Out:
# 0.0    94376
# 1.0    39276
# Name: loss of TPH, dtype: int64

# %%
# Métricas de evaluación 
Ypred= pipe.predict(Xtest)
print(classification_report(Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.80      0.86     94376
#          1.0       0.65      0.86      0.74     39276
#
#     accuracy                           0.82    133652
#    macro avg       0.79      0.83      0.80    133652
# weighted avg       0.85      0.82      0.83    133652

# %%
# Matriz de confusión
matrix=confusion_matrix(Ytest,Ypred,normalize='true'
)
z=[matrix[0].round(2),matrix[1].round(2)]
fig = px.imshow(z, aspect="auto",labels=dict(x="Predicted label", y="True label"),x=["0", "1"],y=["0", "1"]
)

#axis_template = dict(showticklabels = False,ticks = '')
fig.update_layout(height=600,width=600,#title="Matriz de confusión normalizada",
# xaxis = axis_template,yaxis = axis_template,
)
fig.update_xaxes(side="top")
for i,r in enumerate(matrix):
    for k,c in enumerate(r):
        fig.add_annotation(x=k,y=i,
                           text='{}'.format(round(c,2)),
                           showarrow=False, bgcolor="white"
    )
                          
fig.show()

# %%
# Matriz de confusión
matrix=confusion_matrix(Ytest,Ypred,#normalize='true'
)
z=[matrix[0].round(2),matrix[1].round(2)]
fig = px.imshow(z, aspect="auto",labels=dict(x="Predicted label", y="True label"),x=["0", "1"],y=["0", "1"]
)

#axis_template = dict(showticklabels = False,ticks = '')
fig.update_layout(height=600,width=600,#title="Matriz de confusión normalizada",
# xaxis = axis_template,yaxis = axis_template,
)
fig.update_xaxes(side="top")
for i,r in enumerate(matrix):
    for k,c in enumerate(r):
        fig.add_annotation(x=k,y=i,
                           text='{}'.format(round(c,2)),
                           showarrow=False, bgcolor="white"
    )
                          
fig.show()
