# %% [markdown]
# # Visualización de curvas y tratamiento para recomendaciones online

# %%
import pickle
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import warnings
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
warnings.filterwarnings("ignore")

# %%
# Se carga la curva de celda de carga v/s granulometria (dado un subcontexto)
dic1 =  pickle.load(open('..//..//models//pickles//Modelo update Accenture//cc_recommendations.pkl', 'rb'))

# %%
titulos=tuple(dic1.keys())

# %%
#dic1['23'].set_index('gran').plot()
#plt.show()

# %%
# Mostrando curvas de recomendación
fig = make_subplots(
    rows=4, cols=3,
    subplot_titles=titulos,
    )
k=0
for i in range(1,5):
    for j in range(1,4):
        try:
            data=dic1[titulos[k]]
            fig.add_trace(go.Scatter(x=data["gran"], y=data["cc"], ##FF6511
                            mode='lines',
                            name=titulos[k],line=dict(width=3, ),legendgroup = '1'),row=i, col=j) 

            k+=1
        except:
            pass
     



fig.update_layout(height=800, width=1200, title_text="Curvas de recomendación celda de carga vs granulometría",legend_title="Sub-contexto (Edad-Cluster)"#,xaxis6_rangeslider_visible=True
,#template="plotly_dark"
)

fig.show()

# %%
# Se genera dataframe con indices que representan intervalos de granulometria
dic2={}

for i in dic1.keys():
    tmp = dic1[i].set_index('gran')
    left=list((pd.DataFrame(tmp.index).shift(1)+0.5).fillna(0)["gran"])
    right=list((pd.DataFrame(tmp.index)+0.5)["gran"])
    right[-1]=100
    tmp.index=pd.IntervalIndex.from_arrays(
                            left, right)
    dic2[i]=tmp

# %%
dic2["s20"]
# Out:
#                 cc_optimo     cc_base          cc        n       exp_a  \
# (0.0, 30.5]    801.548784  834.848485  801.548784   2197.0 -105.264629
# (30.5, 31.5]   797.969046  840.909091  797.969046   2070.0  -42.042770
# (31.5, 32.5]   794.709123  819.696970  794.709123   2059.0  -76.079237
# (32.5, 33.5]   791.680961  840.909091  791.680961   2209.0  -78.786250
# (33.5, 34.5]   789.670339  837.878788  789.670339   2599.0  -63.406752
# (34.5, 35.5]   786.968107  840.909091  786.968107   2759.0  -95.608422
# (35.5, 36.5]   786.081428  816.666667  786.081428   2774.0  -69.804642
# (36.5, 37.5]   782.884184  813.636364  782.884184   2984.0  -36.382721
# (37.5, 38.5]   780.497794  828.787879  780.497794   3255.0  -61.102744
# (38.5, 39.5]   779.078801  819.696970  779.078801   3563.0  -40.509170
# (39.5, 40.5]   777.336629  831.818182  777.336629   3894.0 -113.420320
# (40.5, 41.5]   777.805958  837.878788  777.805958   4385.0  -74.644416
# (41.5, 42.5]   775.984596  822.727273  775.984596   4866.0  -63.389412
# (42.5, 43.5]   774.682706  825.757576  774.682706   5503.0  -45.612052
# (43.5, 44.5]   773.574051  828.787879  773.574051   6330.0  -48.077811
# (44.5, 45.5]   774.656412  819.696970  774.656412   7074.0  -57.453213
# (45.5, 46.5]   775.949435  822.727273  775.949435   7857.0  -88.725826
# (46.5, 47.5]   777.606914  828.787879  777.606914   8507.0  -77.087047
# (47.5, 48.5]   778.894433  831.818182  778.894433   8651.0 -106.683040
# (48.5, 49.5]   781.168919  850.000000  781.168919   9062.0 -514.031945
# (49.5, 50.5]   783.117167  850.000000  783.117167   9750.0 -104.078731
# (50.5, 51.5]   785.771090  840.909091  785.771090  10055.0  -83.325431
# (51.5, 52.5]   787.321556  828.787879  787.321556  10179.0  -82.559430
# (52.5, 53.5]   790.438998  837.878788  790.438998   9934.0 -149.775355
# (53.5, 54.5]   793.558886  837.878788  793.558886   9984.0 -100.221220
# (54.5, 55.5]   796.639027  850.000000  796.639027  10122.0 -229.214745
# (55.5, 56.5]   801.133574  850.000000  801.133574   9486.0 -117.896786
# (56.5, 57.5]   805.563913  850.000000  805.563913   9300.0 -174.892363
# (57.5, 58.5]   806.097143  846.969697  806.097143   9998.0 -144.060830
# (58.5, 59.5]   807.345527  850.000000  807.345527  10079.0 -147.779470
# (59.5, 60.5]   808.434308  843.939394  808.434308   9404.0  -79.551864
# (60.5, 61.5]   808.578622  850.000000  808.578622   9143.0 -137.195529
# (61.5, 62.5]   809.104209  840.909091  809.104209   9417.0  -56.817714
# (62.5, 63.5]   808.101039  868.181818  808.101039   9536.0 -184.996416
# (63.5, 64.5]   808.662398  865.151515  808.662398   9221.0 -129.482096
# (64.5, 65.5]   807.210996  850.000000  807.210996   8759.0 -102.525370
# (65.5, 66.5]   803.902765  859.090909  803.902765   8497.0 -147.514728
# (66.5, 67.5]   802.544005  813.636364  802.544005   8243.0  -76.095096
# (67.5, 68.5]   800.309573  865.151515  800.309573   8041.0 -183.988244
# (68.5, 69.5]   797.287220  859.090909  797.287220   7743.0 -157.666948
# (69.5, 70.5]   792.840676  874.242424  792.840676   7344.0 -175.824008
# (70.5, 71.5]   788.018975  810.606061  788.018975   6871.0 -121.248119
# (71.5, 72.5]   782.952978  801.515152  782.952978   5922.0 -149.831756
# (72.5, 73.5]   778.356616  798.484848  778.356616   5034.0 -138.048729
# (73.5, 74.5]   773.368281  801.515152  773.368281   4433.0 -288.169057
# (74.5, 75.5]   768.830929  783.333333  768.830929   3742.0 -120.326502
# (75.5, 76.5]   765.738252  783.333333  765.738252   3186.0 -375.952180
# (76.5, 77.5]   761.850011  780.303030  761.850011   2984.0 -119.763851
# (77.5, 78.5]   757.119118  795.454545  757.119118   2608.0 -665.575841
# (78.5, 79.5]   752.168390  746.969697  752.168390   2212.0         NaN
# (79.5, 80.5]   748.032183  768.181818  748.032183   1974.0  -93.649425
# (80.5, 81.5]   743.386595  768.181818  743.386595   1606.0 -152.850513
# (81.5, 100.0]  739.940776  771.212121  739.940776   1227.0  -60.767413
#
#                   exp_b
# (0.0, 30.5]    0.120318
# (30.5, 31.5]   0.045275
# (31.5, 32.5]   0.086985
# (32.5, 33.5]   0.089173
# (33.5, 34.5]   0.071290
# (34.5, 35.5]   0.109614
# (35.5, 36.5]   0.080841
# (36.5, 37.5]   0.039204
# (37.5, 38.5]   0.068726
# (38.5, 39.5]   0.044359
# (39.5, 40.5]   0.131053
# (40.5, 41.5]   0.084586
# (41.5, 42.5]   0.071385
# (42.5, 43.5]   0.050250
# (43.5, 44.5]   0.053284
# (44.5, 45.5]   0.065295
# (45.5, 46.5]   0.103108
# (46.5, 47.5]   0.088432
# (47.5, 48.5]   0.123118
# (48.5, 49.5]   0.598523
# (49.5, 50.5]   0.117009
# (50.5, 51.5]   0.094366
# (51.5, 52.5]   0.093662
# (52.5, 53.5]   0.172966
# (53.5, 54.5]   0.114536
# (54.5, 55.5]   0.264280
# (55.5, 56.5]   0.133731
# (56.5, 57.5]   0.201572
# (57.5, 58.5]   0.165086
# (58.5, 59.5]   0.169214
# (59.5, 60.5]   0.089382
# (60.5, 61.5]   0.156330
# (61.5, 62.5]   0.062794
# (62.5, 63.5]   0.207964
# (63.5, 64.5]   0.145076
# (64.5, 65.5]   0.115813
# (65.5, 66.5]   0.167297
# (66.5, 67.5]   0.088507
# (67.5, 68.5]   0.207704
# (68.5, 69.5]   0.177125
# (69.5, 70.5]   0.196493
# (70.5, 71.5]   0.143538
# (71.5, 72.5]   0.180762
# (72.5, 73.5]   0.167408
# (73.5, 74.5]   0.353410
# (74.5, 75.5]   0.146765
# (75.5, 76.5]   0.474000
# (76.5, 77.5]   0.146906
# (77.5, 78.5]   0.830381
# (78.5, 79.5]        NaN
# (79.5, 80.5]   0.112334
# (80.5, 81.5]   0.189829
# (81.5, 100.0]  0.069458

# %%
# Se guarda diccionario de curvas
pickle.dump(dic2, open('..//..//models//pickles//Modelo update Accenture//cc_recommendations_prod.pkl', 'wb'))
