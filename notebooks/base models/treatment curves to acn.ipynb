# %% [markdown]
# # Visualización de curvas y tratamiento para recomendaciones online

# %%
import pickle
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import warnings
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
warnings.filterwarnings("ignore")

# %%
# Se carga la curva de celda de carga v/s granulometria (dado un subcontexto)
dic1 =  pickle.load(open('..//..//models//cc_recommendations.pkl', 'rb'))

# %%
titulos=tuple(dic1.keys())

# %%
#dic1['23'].set_index('gran').plot()
#plt.show()

# %%
# Mostrando curvas de recomendación
fig = make_subplots(
    rows=4, cols=3,
    subplot_titles=titulos,
    )
k=0
for i in range(1,5):
    for j in range(1,4):
        try:
            data=dic1[titulos[k]]
            fig.add_trace(go.Scatter(x=data["gran"], y=data["cc"], ##FF6511
                            mode='lines',
                            name=titulos[k],line=dict(width=3, ),legendgroup = '1'),row=i, col=j) 

            k+=1
        except:
            pass
     



fig.update_layout(height=800, width=1200, title_text="Curvas de recomendación celda de carga vs granulometría",legend_title="Sub-contexto (Edad-Cluster)"#,xaxis6_rangeslider_visible=True
,#template="plotly_dark"
)

fig.show()

# %%
# Se genera dataframe con indices que representan intervalos de granulometria
dic2={}

for i in dic1.keys():
    tmp = dic1[i].set_index('gran')
    left=list((pd.DataFrame(tmp.index).shift(1)+0.5).fillna(0)["gran"])
    right=list((pd.DataFrame(tmp.index)+0.5)["gran"])
    right[-1]=100
    tmp.index=pd.IntervalIndex.from_arrays(
                            left, right)
    dic2[i]=tmp

# %%
dic2["20"]
# Out:
#                        cc
# (0.0, 30.5]    800.527152
# (30.5, 31.5]   797.268874
# (31.5, 33.5]   793.033113
# (33.5, 34.5]   789.774834
# (34.5, 35.5]   786.842384
# (35.5, 36.5]   784.235762
# (36.5, 38.5]   781.303311
# (38.5, 39.5]   780.000000
# (39.5, 40.5]   778.370861
# (40.5, 41.5]   777.067550
# (41.5, 43.5]   775.438411
# (43.5, 44.5]   775.112583
# (44.5, 45.5]   776.090066
# (45.5, 46.5]   778.045033
# (46.5, 48.5]   780.651656
# (48.5, 49.5]   782.932450
# (49.5, 50.5]   785.213245
# (50.5, 51.5]   788.471523
# (51.5, 53.5]   791.729801
# (53.5, 54.5]   794.988079
# (54.5, 55.5]   799.766887
# (55.5, 56.5]   806.066225
# (56.5, 58.5]   806.717881
# (58.5, 59.5]   807.043709
# (59.5, 60.5]   807.695364
# (60.5, 61.5]   808.998675
# (61.5, 63.5]   809.324503
# (63.5, 64.5]   808.998675
# (64.5, 65.5]   806.392053
# (65.5, 66.5]   803.459603
# (66.5, 68.5]   800.201325
# (68.5, 69.5]   794.988079
# (69.5, 70.5]   790.296159
# (70.5, 71.5]   783.909934
# (71.5, 72.5]   780.912318
# (72.5, 73.5]   774.395762
# (73.5, 74.5]   770.485828
# (74.5, 75.5]   765.989404
# (75.5, 76.5]   762.405298
# (76.5, 77.5]   756.540397
# (77.5, 78.5]   753.803444
# (78.5, 79.5]   748.720530
# (79.5, 80.5]   744.419603
# (80.5, 100.0]  742.203974

# %%
# Se guarda diccionario de curvas
pickle.dump(dic2, open('..//..//models//cc_recommendations_prod.pkl', 'wb'))
