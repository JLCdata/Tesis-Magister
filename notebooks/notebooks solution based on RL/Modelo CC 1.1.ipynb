# %% [markdown]
# # Modelo CC

# %%
# Modelo TPH
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import lightgbm as lgb
import xgboost as xgb
#import d3rlpy
from tqdm.notebook import tqdm_notebook
from tqdm import tqdm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
from datetime import datetime
from datetime import timedelta
import re
from dateutil.parser import parse
import string
import warnings
warnings.filterwarnings('ignore')
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_percentage_error
import missingno as msno
from plotly.subplots import make_subplots
from sklearn.preprocessing import MinMaxScaler
import scipy
import researchpy as rp
from matplotlib.offsetbox import AnchoredText
#import pacmap
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
import plotly.express as px
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split 
# Import Halving Grid Search
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingGridSearchCV
import xgboost as xgb
from scipy.stats import kurtosis,skew
from numpy import mean,sqrt,square
from scipy.fftpack import fft, fftfreq
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import PredefinedSplit
import shap
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import precision_recall_curve
sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 100

# %%
df_events = pd.read_csv("../../data/processed data/events_08September2023.csv")
df_events.head(1)
# Out:
#         inicio perdida          fin perdida        inicio evento  \
# 0  2018-01-01 00:51:00  2018-01-01 01:30:00  2018-01-01 00:41:00
#
#             fin evento  impacto TPH  variación HH TPH  std HH TPH  \
# 0  2018-01-01 01:40:00     6.131858             False         0.0
#
#    Causalidad sistema de control  Causalidad molino vacio Tipo de evento Flag  \
# 0                          False                    False  Embancamiento    E
#
#    duración evento
# 0             39.0

# %%
df_events_train=df_events[(df_events["Flag"]=="E") | (df_events["Flag"]=="S")]
df_events_train.head(1)
# Out:
#         inicio perdida          fin perdida        inicio evento  \
# 0  2018-01-01 00:51:00  2018-01-01 01:30:00  2018-01-01 00:41:00
#
#             fin evento  impacto TPH  variación HH TPH  std HH TPH  \
# 0  2018-01-01 01:40:00     6.131858             False         0.0
#
#    Causalidad sistema de control  Causalidad molino vacio Tipo de evento Flag  \
# 0                          False                    False  Embancamiento    E
#
#    duración evento
# 0             39.0

# %%
tags=['granulometry', 'charge cell', 'speed', 'solid percentage', 'water','TPH', 'HH TPH', 'LL charge cell', 'HH charge cell',

#"loss of TPH","start loss of TPH"	,"end loss of TPH",		"start low load cell",	"end low load cell",		"start high load cell",	"end high load cell","high load cell","low load cell",
#"Optimizando tonelaje","Limitado por Peso",
"delta HH TPH","delta HH charge cell",
#'pyrite law', 'chalcopyrite law','chalcocite law', 'crusher index', 'ball work index','bornite law','covelin law',
'sag power index',

"Edad"
]

# %%
df_full=pd.read_csv("../../data/processed data/feature_engineering_event_to_train_09September2023.csv",parse_dates=['Timestamp'], index_col='Timestamp').drop(["Unnamed: 0"],axis=1)
df_full["start high load cell"]=df_full["start high load cell"].shift(-5)
df_full.dropna(inplace=True)
df_full.head()
# Out:
#                      granulometry  charge cell     speed  solid percentage  \
# Timestamp
# 2018-01-01 11:53:00     64.423188   847.444023  8.392914         72.049899
# 2018-01-01 11:54:00     64.413594   849.008643  8.374861         71.965625
# 2018-01-01 11:55:00     64.343227   851.462556  8.375239         71.975988
# 2018-01-01 11:56:00     64.282369   854.789823  8.416340         71.929055
# 2018-01-01 11:57:00     64.051834   858.138813  8.438009         71.884174
#
(t-2)  \
# Timestamp
# 2018-01-01 11:53:00                   92.4                   92.4
# 2018-01-01 11:54:00                   92.4                   92.4
# 2018-01-01 11:55:00                   92.4                   92.4
# 2018-01-01 11:56:00                   92.4                   92.4
# 2018-01-01 11:57:00                   92.4                   92.4
#
#                      sag power index_(t-3)  sag power index_(t-4)  \
# Timestamp
# 2018-01-01 11:53:00                   92.4                   92.4
# 2018-01-01 11:54:00                   92.4                   92.4
# 2018-01-01 11:55:00                   92.4                   92.4
# 2018-01-01 11:56:00                   92.4                   92.4
# 2018-01-01 11:57:00                   92.4                   92.4
#
#                      sag power index_(t-5)  Edad_(t-1)  Edad_(t-2)  \
# Timestamp
# 2018-01-01 11:53:00                   92.4         1.0         1.0
# 2018-01-01 11:54:00                   92.4         1.0         1.0
# 2018-01-01 11:55:00                   92.4         1.0         1.0
# 2018-01-01 11:56:00                   92.4         1.0         1.0
# 2018-01-01 11:57:00                   92.4         1.0         1.0
#
#                      Edad_(t-3)  Edad_(t-4)  Edad_(t-5) Flag
# Timestamp
# 2018-01-01 11:53:00         1.0         1.0         1.0    E
# 2018-01-01 11:54:00         1.0         1.0         1.0    E
# 2018-01-01 11:55:00         1.0         1.0         1.0    E
# 2018-01-01 11:56:00         1.0         1.0         1.0    E
# 2018-01-01 11:57:00         1.0         1.0         1.0    E

# %%
df_full["Edad"]=df_full["Edad"].astype("category")

# %%
df_full["start high load cell"].value_counts()
# Out:
# 0.0    361747
# 1.0      3729
# Name: start high load cell, dtype: int64

# %%
others=[ 'start loss of TPH',
 'end loss of TPH',
 'start low load cell',
 'end low load cell',
 'end high load cell','high load cell',
 'low load cell','pyrite law', 'chalcopyrite law','chalcocite law', 
 'crusher index', 'ball work index','bornite law','covelin law',"Flag"]

# %%
features1=["Edad","random","delta HH charge cell","HH TPH"]+[i for i in df_full.columns if (not re.match(".*water",i)) and (not re.match(".*delta",i)) and (not re.match(".*Edad",i)) and (not re.match(".*TPH",i))]
features = list(set(features1).difference(set(others)))

# %%
df_full['random'] = np.random.rand(df_full.shape[0])

# %%
#df_full=df_full[features]

# %%
# Entrenamiento
entrenamiento=pd.concat([df_full["2020-01":"2020-03"],df_full["2020-05"],df_full["2020-07":"2020-12"],df_full["2021-01":"2021-08"],df_full["2021-10"],df_full["2021-12"]])[features]
entrenamiento.head(1)
# Out:
#                      max_solid percentage_3  max_sag power index_5  \
# Timestamp
# 2020-01-10 01:55:00               73.888991                98.5569
#
#                      max_sag power index_3  mean_charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00                98.5569           815.021558
#
#                      granulometry_(t-1)  granulometry_(t-3)  \
# Timestamp
# 2020-01-10 01:55:00           45.281383            45.41929
#
#                      granulometry_(t-2)  start high load cell  HH TPH  \
# Timestamp
# 2020-01-10 01:55:00           45.364634                   0.0  4100.0
#
#                      min_solid percentage_10  sag power index_(t-2)  \
# Timestamp
# 2020-01-10 01:55:00                73.073047                98.5569
#
#                      var_granulometry_10  mean_solid percentage_5  \
# Timestamp
# 2020-01-10 01:55:00             0.009481                73.855673
#
#                      min_charge cell_10  rms_HH charge cell_5  charge cell  \
# Timestamp
# 2020-01-10 01:55:00          810.632019                 850.0   821.121423
#
#                      max_granulometry_5  mean_charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00           45.472911          819.805588
#
#                      var_LL charge cell_10  mean_speed_5  min_granulometry_3  \
# Timestamp
# 2020-01-10 01:55:00                    0.0      9.249917           45.142813
#
#                      max_charge cell_10  min_speed_5  mean_solid percentage_3  \
# Timestamp
# 2020-01-10 01:55:00          821.121423     9.249444                73.860999
#
#                      mean_sag power index_10  solid percentage_(t-5)  \
# Timestamp
# 2020-01-10 01:55:00                  98.5569               73.689758
#
#                       var_speed_3  solid percentage_(t-2)  \
# Timestamp
# 2020-01-10 01:55:00  2.296189e-08               73.859426
#
#                      min_sag power index_5  rms_charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00                98.5569         819.806239
#
#                      min_LL charge cell_3  max_granulometry_10  \
# Timestamp
# 2020-01-10 01:55:00                 770.0            45.472911
#
#                      LL charge cell_(t-1)  rms_HH charge cell_3  speed_(t-4)  \
# Timestamp
# 2020-01-10 01:55:00                 770.0                 850.0     9.250139
#
#                      LL charge cell_(t-4)  mean_sag power index_3  \
# Timestamp
# 2020-01-10 01:55:00                 770.0                 98.5569
#
#                      var_speed_10  rms_granulometry_3  speed_(t-1)  \
# Timestamp
# 2020-01-10 01:55:00  1.237283e-07           45.263036     9.249444
#
#                      rms_HH charge cell_10  LL charge cell  \
# Timestamp
# 2020-01-10 01:55:00                  850.0           770.0
#
#                      var_LL charge cell_3  max_granulometry_3  \
# Timestamp
# 2020-01-10 01:55:00                   0.0           45.364634
#
#                      max_LL charge cell_5  var_sag power index_3  \
# Timestamp
# 2020-01-10 01:55:00                 770.0                    0.0
#
#                      rms_LL charge cell_5  max_sag power index_10  \
# Timestamp
# 2020-01-10 01:55:00                 770.0                 98.5569
#
#                      rms_solid percentage_3  max_solid percentage_10  \
# Timestamp
# 2020-01-10 01:55:00               73.861002                73.888991
#
#                      charge cell_(t-5)  mean_HH charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00         813.157471                   850.0
#
#                      var_HH charge cell_3  var_solid percentage_5  \
# Timestamp
# 2020-01-10 01:55:00                   0.0                0.001003
#
#                      min_HH charge cell_10  speed_(t-2)  var_charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00                  850.0     9.249657           12.260027
#
#                      charge cell_(t-4)  HH charge cell_(t-1)  \
# Timestamp
# 2020-01-10 01:55:00          814.65726                 850.0
#
#                      HH charge cell_(t-4)  min_charge cell_3  max_speed_3  \
# Timestamp
# 2020-01-10 01:55:00                 850.0         818.598114     9.249814
#
#                      min_charge cell_5  mean_HH charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00          814.65726                  850.0
#
#                      mean_solid percentage_10  HH charge cell  \
# Timestamp
# 2020-01-10 01:55:00                 73.640117           850.0
#
#                      granulometry_(t-5)  HH charge cell_(t-2)  \
# Timestamp
# 2020-01-10 01:55:00           45.454103                 850.0
#
#                      mean_LL charge cell_3  sag power index_(t-5)  \
# Timestamp
# 2020-01-10 01:55:00                  770.0                98.5569
#
#                      min_LL charge cell_5  sag power index  \
# Timestamp
# 2020-01-10 01:55:00                 770.0          98.5569
#
#                      min_granulometry_5  rms_LL charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00           45.142813                 770.0
#
#                      rms_charge cell_5  mean_sag power index_5  \
# Timestamp
# 2020-01-10 01:55:00          818.05287                 98.5569
#
#                      rms_charge cell_10  HH charge cell_(t-3)  \
# Timestamp
# 2020-01-10 01:55:00          815.029079                 850.0
#
#                      solid percentage_(t-3)  mean_speed_10  \
# Timestamp
# 2020-01-10 01:55:00               73.888403       9.249984
#
#                      var_sag power index_10  min_LL charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00            2.019484e-28                  770.0
#
#                      sag power index_(t-1)  granulometry_(t-4)  \
# Timestamp
# 2020-01-10 01:55:00                98.5569           45.472911
#
#                      var_solid percentage_10  min_solid percentage_5  \
# Timestamp
# 2020-01-10 01:55:00                 0.067765               73.806967
#
#                      max_charge cell_5  speed_(t-3)  solid percentage_(t-4)  \
# Timestamp
# 2020-01-10 01:55:00         821.121423     9.250532               73.806967
#
#                     Edad  rms_solid percentage_10  max_LL charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00  1.0                73.640577                 770.0
#
#                      solid percentage  mean_granulometry_5  \
# Timestamp
# 2020-01-10 01:55:00         73.888991            45.336206
#
#                      max_HH charge cell_10  rms_granulometry_5  \
# Timestamp
# 2020-01-10 01:55:00                  850.0           45.336353
#
#                      sag power index_(t-3)  min_HH charge cell_5  \
# Timestamp
# 2020-01-10 01:55:00                98.5569                 850.0
#
#                      max_speed_10  delta HH charge cell  rms_speed_3  \
# Timestamp
# 2020-01-10 01:55:00      9.250532             28.878577     9.249638
#
#                      min_solid percentage_3  max_HH charge cell_5  \
# Timestamp
# 2020-01-10 01:55:00                73.83458                 850.0
#
#                      min_sag power index_10  LL charge cell_(t-3)  \
# Timestamp
# 2020-01-10 01:55:00                 98.5569                 770.0
#
#                      var_LL charge cell_5  max_speed_5  rms_granulometry_10  \
# Timestamp
# 2020-01-10 01:55:00                   0.0     9.250532            45.387341
#
#                      mean_speed_3  speed_(t-5)   var_speed_5  \
# Timestamp
# 2020-01-10 01:55:00      9.249638     9.249932  1.458743e-07
#
#                      rms_sag power index_10  var_solid percentage_3   random  \
# Timestamp
# 2020-01-10 01:55:00                 98.5569                0.000495  0.28208
#
#                      charge cell_(t-1)  min_sag power index_3  \
# Timestamp
# 2020-01-10 01:55:00         819.697227                98.5569
#
#                      mean_granulometry_3  rms_sag power index_5  \
# Timestamp
# 2020-01-10 01:55:00            45.262943                98.5569
#
#                      max_charge cell_3  mean_LL charge cell_5  \
# Timestamp
# 2020-01-10 01:55:00         821.121423                  770.0
#
#                      LL charge cell_(t-2)  charge cell_(t-3)  \
# Timestamp
# 2020-01-10 01:55:00                 770.0         816.173527
#
#                      LL charge cell_(t-5)  mean_LL charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00                 770.0                   770.0
#
#                      var_granulometry_5  mean_charge cell_5  \
# Timestamp
# 2020-01-10 01:55:00            0.013361           818.04951
#
#                      sag power index_(t-4)  rms_speed_10  \
# Timestamp
# 2020-01-10 01:55:00                98.5569      9.249984
#
#                      rms_solid percentage_5  var_sag power index_5  \
# Timestamp
# 2020-01-10 01:55:00                73.85568                    0.0
#
#                      rms_speed_5  rms_sag power index_3  \
# Timestamp
# 2020-01-10 01:55:00     9.249917                98.5569
#
#                      max_solid percentage_5  var_HH charge cell_5  \
# Timestamp
# 2020-01-10 01:55:00               73.888991                   0.0
#
#                      solid percentage_(t-1)  min_granulometry_10  \
# Timestamp
# 2020-01-10 01:55:00                73.83458            45.142813
#
#                      min_HH charge cell_3  HH charge cell_(t-5)  \
# Timestamp
# 2020-01-10 01:55:00                 850.0                 850.0
#
#                      var_charge cell_5  granulometry  max_HH charge cell_3  \
# Timestamp
# 2020-01-10 01:55:00           5.495852     45.142813                 850.0
#
#                      charge cell_(t-2)  min_speed_3  var_HH charge cell_10  \
# Timestamp
# 2020-01-10 01:55:00         818.598114     9.249444                    0.0
#
#                      rms_LL charge cell_10  max_LL charge cell_10     speed  \
# Timestamp
# 2020-01-10 01:55:00                  770.0                  770.0  9.249814
#
#                      min_speed_10  var_charge cell_3  var_granulometry_3  \
# Timestamp
# 2020-01-10 01:55:00      9.249444           1.067052            0.008371
#
#                      mean_granulometry_10  mean_HH charge cell_5
# Timestamp
# 2020-01-10 01:55:00             45.387237                  850.0

# %%
# Validación
validacion=pd.concat([df_full["2020-06"],df_full["2021-11"]])[features]
validacion.head(1)
# Out:
#             max_solid percentage_3  max_sag power index_5  \
# Timestamp
# 2020-06-01               65.252047                  183.0
#
#             max_sag power index_3  mean_charge cell_10  granulometry_(t-1)  \
# Timestamp
# 2020-06-01                  183.0           812.741714           52.479402
#
#             granulometry_(t-3)  granulometry_(t-2)  start high load cell  \
# Timestamp
# 2020-06-01           51.848723           52.191338                   0.0
#
#             HH TPH  min_solid percentage_10  sag power index_(t-2)  \
# Timestamp
# 2020-06-01  4400.0                64.838669                  183.0
#
#             var_granulometry_10  mean_solid percentage_5  min_charge cell_10  \
# Timestamp
# 2020-06-01             0.462283                65.098793          808.370729
#
#             rms_HH charge cell_5  charge cell  max_granulometry_5  \
# Timestamp
# 2020-06-01                 820.0   811.822555            52.80404
#
#             mean_charge cell_3  var_LL charge cell_10  mean_speed_5  \
# Timestamp
# 2020-06-01          810.234924                    0.0      8.874422
#
#             min_granulometry_3  max_charge cell_10  min_speed_5  \
# Timestamp
# 2020-06-01           52.191338          820.841222     8.870746
#
#             mean_solid percentage_3  mean_sag power index_10  \
# Timestamp
# 2020-06-01                 65.09123                    183.0
#
#             solid percentage_(t-5)  var_speed_3  solid percentage_(t-2)  \
# Timestamp
# 2020-06-01               65.138229     0.000009               64.977265
#
#             min_sag power index_5  rms_charge cell_3  min_LL charge cell_3  \
# Timestamp
# 2020-06-01                  183.0         810.236173                 740.0
#
#             max_granulometry_10  LL charge cell_(t-1)  rms_HH charge cell_3  \
# Timestamp
# 2020-06-01             52.80404                 740.0                 820.0
#
#             speed_(t-4)  LL charge cell_(t-4)  mean_sag power index_3  \
# Timestamp
# 2020-06-01      8.87551                 740.0                   183.0
#
#             var_speed_10  rms_granulometry_3  speed_(t-1)  \
# Timestamp
# 2020-06-01      0.000008            52.49219     8.873753
#
#             rms_HH charge cell_10  LL charge cell  var_LL charge cell_3  \
# Timestamp
# 2020-06-01                  820.0           740.0                   0.0
#
#             max_granulometry_3  max_LL charge cell_5  var_sag power index_3  \
# Timestamp
# 2020-06-01            52.80404                 740.0                    0.0
#
#             rms_LL charge cell_5  max_sag power index_10  \
# Timestamp
# 2020-06-01                 740.0                   183.0
#
#             rms_solid percentage_3  max_solid percentage_10  \
# Timestamp
# 2020-06-01               65.091335                65.252047
#
#             charge cell_(t-5)  mean_HH charge cell_10  var_HH charge cell_3  \
# Timestamp
# 2020-06-01         810.076823                   820.0                   0.0
#
#             var_solid percentage_5  min_HH charge cell_10  speed_(t-2)  \
# Timestamp
# 2020-06-01                0.008295                  820.0     8.870746
#
#             var_charge cell_10  charge cell_(t-4)  HH charge cell_(t-1)  \
# Timestamp
# 2020-06-01           18.820933          808.79535                 820.0
#
#             HH charge cell_(t-4)  min_charge cell_3  max_speed_3  \
# Timestamp
# 2020-06-01                 820.0         808.370729     8.877953
#
#             min_charge cell_5  mean_HH charge cell_3  \
# Timestamp
# 2020-06-01         808.370729                  820.0
#
#             mean_solid percentage_10  HH charge cell  granulometry_(t-5)  \
# Timestamp
# 2020-06-01                 65.042908           820.0           51.563434
#
#             HH charge cell_(t-2)  mean_LL charge cell_3  \
# Timestamp
# 2020-06-01                 820.0                  740.0
#
#             sag power index_(t-5)  min_LL charge cell_5  sag power index  \
# Timestamp
# 2020-06-01                  183.0                 740.0            183.0
#
#             min_granulometry_5  rms_LL charge cell_3  rms_charge cell_5  \
# Timestamp
# 2020-06-01           51.628653                 740.0         809.627834
#
#             mean_sag power index_5  rms_charge cell_10  HH charge cell_(t-3)  \
# Timestamp
# 2020-06-01                   183.0          812.753293                 820.0
#
#             solid percentage_(t-3)  mean_speed_10  var_sag power index_10  \
# Timestamp
# 2020-06-01               65.110449        8.87382                     0.0
#
#             min_LL charge cell_10  sag power index_(t-1)  granulometry_(t-4)  \
# Timestamp
# 2020-06-01                  740.0                  183.0           51.628653
#
#             var_solid percentage_10  min_solid percentage_5  \
# Timestamp
# 2020-06-01                 0.012208               64.977265
#
#             max_charge cell_5  speed_(t-3)  solid percentage_(t-4) Edad  \
# Timestamp
# 2020-06-01         811.822555      8.87415               65.109825  0.0
#
#             rms_solid percentage_10  max_LL charge cell_3  solid percentage  \
# Timestamp
# 2020-06-01                65.043002                 740.0         65.044377
#
#             mean_granulometry_5  max_HH charge cell_10  rms_granulometry_5  \
# Timestamp
# 2020-06-01            52.190431                  820.0           52.192141
#
#             sag power index_(t-3)  min_HH charge cell_5  max_speed_10  \
# Timestamp
# 2020-06-01                  183.0                 820.0      8.877953
#
#             delta HH charge cell  rms_speed_3  min_solid percentage_3  \
# Timestamp
# 2020-06-01              8.177445     8.874151               64.977265
#
#             max_HH charge cell_5  min_sag power index_10  \
# Timestamp
# 2020-06-01                 820.0                   183.0
#
#             LL charge cell_(t-3)  var_LL charge cell_5  max_speed_5  \
# Timestamp
# 2020-06-01                 740.0                   0.0     8.877953
#
#             rms_granulometry_10  mean_speed_3  speed_(t-5)  var_speed_5  \
# Timestamp
# 2020-06-01            51.653938      8.874151      8.86769     0.000006
#
#             rms_sag power index_10  var_solid percentage_3    random  \
# Timestamp
# 2020-06-01                   183.0                0.013682  0.325398
#
#             charge cell_(t-1)  min_sag power index_3  mean_granulometry_3  \
# Timestamp
# 2020-06-01         810.511489                  183.0            52.491593
#
#             rms_sag power index_5  max_charge cell_3  mean_LL charge cell_5  \
# Timestamp
# 2020-06-01                  183.0         811.822555                  740.0
#
#             LL charge cell_(t-2)  charge cell_(t-3)  LL charge cell_(t-5)  \
# Timestamp
# 2020-06-01                 740.0         808.633576                 740.0
#
#             mean_LL charge cell_10  var_granulometry_5  mean_charge cell_5  \
# Timestamp
# 2020-06-01                   740.0            0.178476           809.62674
#
#             sag power index_(t-4)  rms_speed_10  rms_solid percentage_5  \
# Timestamp
# 2020-06-01                  183.0       8.87382               65.098856
#
#             var_sag power index_5  rms_speed_5  rms_sag power index_3  \
# Timestamp
# 2020-06-01                    0.0     8.874423                  183.0
#
#             max_solid percentage_5  var_HH charge cell_5  \
# Timestamp
# 2020-06-01               65.252047                   0.0
#
#             solid percentage_(t-1)  min_granulometry_10  min_HH charge cell_3  \
# Timestamp
# 2020-06-01               65.252047            50.482627                 820.0
#
#             HH charge cell_(t-5)  var_charge cell_5  granulometry  \
# Timestamp
# 2020-06-01                 820.0           1.771907      52.80404
#
#             max_HH charge cell_3  charge cell_(t-2)  min_speed_3  \
# Timestamp
# 2020-06-01                 820.0         808.370729     8.870746
#
#             var_HH charge cell_10  rms_LL charge cell_10  \
# Timestamp
# 2020-06-01                    0.0                  740.0
#
#             max_LL charge cell_10     speed  min_speed_10  var_charge cell_3  \
# Timestamp
# 2020-06-01                  740.0  8.877953       8.86769           2.024094
#
#             var_granulometry_3  mean_granulometry_10  mean_HH charge cell_5
# Timestamp
# 2020-06-01            0.062642             51.649463                  820.0

# %%
# Test
test=pd.concat([df_full["2020-04"],df_full["2021-09"],df_full["2022"]])[features]
test.head(1)
# Out:
#                      max_solid percentage_3  max_sag power index_5  \
# Timestamp
# 2020-04-01 00:46:00               65.329404               116.3165
#
#                      max_sag power index_3  mean_charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00               116.3165            780.41874
#
#                      granulometry_(t-1)  granulometry_(t-3)  \
# Timestamp
# 2020-04-01 00:46:00           29.733998           29.760031
#
#                      granulometry_(t-2)  start high load cell  HH TPH  \
# Timestamp
# 2020-04-01 00:46:00           29.744036                   0.0  3800.0
#
#                      min_solid percentage_10  sag power index_(t-2)  \
# Timestamp
# 2020-04-01 00:46:00                65.156372               116.3165
#
#                      var_granulometry_10  mean_solid percentage_5  \
# Timestamp
# 2020-04-01 00:46:00             0.068108                65.298608
#
#                      min_charge cell_10  rms_HH charge cell_5  charge cell  \
# Timestamp
# 2020-04-01 00:46:00          771.520647                 840.0   791.153357
#
#                      max_granulometry_5  mean_charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00           29.760031          788.101917
#
#                      var_LL charge cell_10  mean_speed_5  min_granulometry_3  \
# Timestamp
# 2020-04-01 00:46:00                    0.0       9.25011           29.733998
#
#                      max_charge cell_10  min_speed_5  mean_solid percentage_3  \
# Timestamp
# 2020-04-01 00:46:00          791.153357     9.249442                65.304234
#
#                      mean_sag power index_10  solid percentage_(t-5)  \
# Timestamp
# 2020-04-01 00:46:00                 116.3165               65.242806
#
#                       var_speed_3  solid percentage_(t-2)  \
# Timestamp
# 2020-04-01 00:46:00  5.292709e-07               65.307874
#
#                      min_sag power index_5  rms_charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00               116.3165           788.1062
#
#                      min_LL charge cell_3  max_granulometry_10  \
# Timestamp
# 2020-04-01 00:46:00                 760.0            30.489354
#
#                      LL charge cell_(t-1)  rms_HH charge cell_3  speed_(t-4)  \
# Timestamp
# 2020-04-01 00:46:00                 760.0                 840.0     9.249451
#
#                      LL charge cell_(t-4)  mean_sag power index_3  \
# Timestamp
# 2020-04-01 00:46:00                 760.0                116.3165
#
#                      var_speed_10  rms_granulometry_3  speed_(t-1)  \
# Timestamp
# 2020-04-01 00:46:00  3.861022e-07           29.743053     9.249442
#
#                      rms_HH charge cell_10  LL charge cell  \
# Timestamp
# 2020-04-01 00:46:00                  840.0           760.0
#
#                      var_LL charge cell_3  max_granulometry_3  \
# Timestamp
# 2020-04-01 00:46:00                   0.0           29.751123
#
#                      max_LL charge cell_5  var_sag power index_3  \
# Timestamp
# 2020-04-01 00:46:00                 760.0                    0.0
#
#                      rms_LL charge cell_5  max_sag power index_10  \
# Timestamp
# 2020-04-01 00:46:00                 760.0                116.3165
#
#                      rms_solid percentage_3  max_solid percentage_10  \
# Timestamp
# 2020-04-01 00:46:00               65.304237                65.350147
#
#                      charge cell_(t-5)  mean_HH charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00         777.497024                   840.0
#
#                      var_HH charge cell_3  var_solid percentage_5  \
# Timestamp
# 2020-04-01 00:46:00                   0.0                0.000429
#
#                      min_HH charge cell_10  speed_(t-2)  var_charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00                  840.0     9.251178           38.342387
#
#                      charge cell_(t-4)  HH charge cell_(t-1)  \
# Timestamp
# 2020-04-01 00:46:00          781.56662                 840.0
#
#                      HH charge cell_(t-4)  min_charge cell_3  max_speed_3  \
# Timestamp
# 2020-04-01 00:46:00                 840.0         784.803311     9.251178
#
#                      min_charge cell_5  mean_HH charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00          781.56662                  840.0
#
#                      mean_solid percentage_10  HH charge cell  \
# Timestamp
# 2020-04-01 00:46:00                 65.288267           840.0
#
#                      granulometry_(t-5)  HH charge cell_(t-2)  \
# Timestamp
# 2020-04-01 00:46:00           29.769485                 840.0
#
#                      mean_LL charge cell_3  sag power index_(t-5)  \
# Timestamp
# 2020-04-01 00:46:00                  760.0               116.3165
#
#                      min_LL charge cell_5  sag power index  \
# Timestamp
# 2020-04-01 00:46:00                 760.0         116.3165
#
#                      min_granulometry_5  rms_LL charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00           29.733998                 760.0
#
#                      rms_charge cell_5  mean_sag power index_5  \
# Timestamp
# 2020-04-01 00:46:00         785.945918                116.3165
#
#                      rms_charge cell_10  HH charge cell_(t-3)  \
# Timestamp
# 2020-04-01 00:46:00          780.443304                 840.0
#
#                      solid percentage_(t-3)  mean_speed_10  \
# Timestamp
# 2020-04-01 00:46:00               65.275514       9.249905
#
#                      var_sag power index_10  min_LL charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00            2.019484e-28                  760.0
#
#                      sag power index_(t-1)  granulometry_(t-4)  \
# Timestamp
# 2020-04-01 00:46:00               116.3165           29.756685
#
#                      var_solid percentage_10  min_solid percentage_5  \
# Timestamp
# 2020-04-01 00:46:00                 0.002804               65.275422
#
#                      max_charge cell_5  speed_(t-3)  solid percentage_(t-4)  \
# Timestamp
# 2020-04-01 00:46:00         791.153357     9.250517               65.304826
#
#                     Edad  rms_solid percentage_10  max_LL charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00  2.0                65.288289                 760.0
#
#                      solid percentage  mean_granulometry_5  \
# Timestamp
# 2020-04-01 00:46:00         65.329404            29.749175
#
#                      max_HH charge cell_10  rms_granulometry_5  \
# Timestamp
# 2020-04-01 00:46:00                  840.0           29.749176
#
#                      sag power index_(t-3)  min_HH charge cell_5  \
# Timestamp
# 2020-04-01 00:46:00               116.3165                 840.0
#
#                      max_speed_10  delta HH charge cell  rms_speed_3  \
# Timestamp
# 2020-04-01 00:46:00      9.251178             48.846643     9.250194
#
#                      min_solid percentage_3  max_HH charge cell_5  \
# Timestamp
# 2020-04-01 00:46:00               65.275422                 840.0
#
#                      min_sag power index_10  LL charge cell_(t-3)  \
# Timestamp
# 2020-04-01 00:46:00                116.3165                 760.0
#
#                      var_LL charge cell_5  max_speed_5  rms_granulometry_10  \
# Timestamp
# 2020-04-01 00:46:00                   0.0     9.251178            29.939598
#
#                      mean_speed_3  speed_(t-5)   var_speed_5  \
# Timestamp
# 2020-04-01 00:46:00      9.250194     9.249247  4.416996e-07
#
#                      rms_sag power index_10  var_solid percentage_3    random  \
# Timestamp
# 2020-04-01 00:46:00                116.3165                0.000492  0.479425
#
#                      charge cell_(t-1)  min_sag power index_3  \
# Timestamp
# 2020-04-01 00:46:00         788.349081               116.3165
#
#                      mean_granulometry_3  rms_sag power index_5  \
# Timestamp
# 2020-04-01 00:46:00            29.743052               116.3165
#
#                      max_charge cell_3  mean_LL charge cell_5  \
# Timestamp
# 2020-04-01 00:46:00         791.153357                  760.0
#
#                      LL charge cell_(t-2)  charge cell_(t-3)  \
# Timestamp
# 2020-04-01 00:46:00                 760.0         783.820389
#
#                      LL charge cell_(t-5)  mean_LL charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00                 760.0                   760.0
#
#                      var_granulometry_5  mean_charge cell_5  \
# Timestamp
# 2020-04-01 00:46:00            0.000087          785.938552
#
#                      sag power index_(t-4)  rms_speed_10  \
# Timestamp
# 2020-04-01 00:46:00               116.3165      9.249905
#
#                      rms_solid percentage_5  var_sag power index_5  \
# Timestamp
# 2020-04-01 00:46:00               65.298612           2.019484e-28
#
#                      rms_speed_5  rms_sag power index_3  \
# Timestamp
# 2020-04-01 00:46:00      9.25011               116.3165
#
#                      max_solid percentage_5  var_HH charge cell_5  \
# Timestamp
# 2020-04-01 00:46:00               65.329404                   0.0
#
#                      solid percentage_(t-1)  min_granulometry_10  \
# Timestamp
# 2020-04-01 00:46:00               65.275422            29.733998
#
#                      min_HH charge cell_3  HH charge cell_(t-5)  \
# Timestamp
# 2020-04-01 00:46:00                 840.0                 840.0
#
#                      var_charge cell_5  granulometry  max_HH charge cell_3  \
# Timestamp
# 2020-04-01 00:46:00          11.578806     29.751123                 840.0
#
#                      charge cell_(t-2)  min_speed_3  var_HH charge cell_10  \
# Timestamp
# 2020-04-01 00:46:00         784.803311     9.249442                    0.0
#
#                      rms_LL charge cell_10  max_LL charge cell_10     speed  \
# Timestamp
# 2020-04-01 00:46:00                  760.0                  760.0  9.249962
#
#                      min_speed_10  var_charge cell_3  var_granulometry_3  \
# Timestamp
# 2020-04-01 00:46:00      9.249155           6.751061            0.000049
#
#                      mean_granulometry_10  mean_HH charge cell_5
# Timestamp
# 2020-04-01 00:46:00             29.938461                  840.0

# %%
tags=df_full.columns.to_list()
tags.remove("loss of TPH")

# %%
# Sobremuestreo: Aumentar numero de datos de la clase minoritaria
# ROS(Duplica clases):
ros=RandomOverSampler(random_state=0) # Random_state=0

# ROS:
Xtrain, Ytrain=ros.fit_resample(entrenamiento,entrenamiento[["start high load cell"]])

# %%
Ytrain["start high load cell"]=Ytrain["start high load cell"].astype("int")

# %%
Xtrain=Xtrain.drop(columns=["start high load cell"])

# %%
#scaler = MinMaxScaler()
#Xtrain=pd.DataFrame(scaler.fit_transform(Xtrain),columns=Xtrain.columns,index=Xtrain.index)
#Xtrain["Edad"]=entrenamiento["Edad"].reset_index(drop=True)
#Xtrain.head()

# %%
# Yval reg
Yval=validacion["start high load cell"]
Xval=validacion.drop(columns=["start high load cell"])
#Xval=pd.DataFrame(scaler.transform(Xval),columns=Xval.columns,index=Xval.index)
#Xval["Edad"]=validacion["Edad"]
Xval.head()
# Out:
#                      max_solid percentage_3  max_sag power index_5  \
# Timestamp
# 2020-06-01 00:00:00               65.252047                  183.0
# 2020-06-01 00:01:00               65.252047                  183.0
# 2020-06-01 00:02:00               65.117248                  183.0
# 2020-06-01 00:03:00               65.117248                  183.0
# 2020-06-01 00:04:00               65.048301                  183.0
#
#                      max_sag power index_3  mean_charge cell_10  \
# Timestamp
# 2020-06-01 00:00:00                  183.0           812.741714
# 2020-06-01 00:01:00                  183.0           811.977491
# 2020-06-01 00:02:00                  183.0           811.531349
# 2020-06-01 00:03:00                  183.0           811.361865
# 2020-06-01 00:04:00                  183.0           811.328637
#
#                      granulometry_(t-1)  granulometry_(t-3)  \
# Timestamp
# 2020-06-01 00:00:00           52.479402           51.848723
# 2020-06-01 00:01:00           52.804040           52.191338
# 2020-06-01 00:02:00           53.156466           52.479402
# 2020-06-01 00:03:00           53.727042           52.804040
# 2020-06-01 00:04:00           54.287458           53.156466
#
#                      granulometry_(t-2)  HH TPH  min_solid percentage_10  \
# Timestamp
# 2020-06-01 00:00:00           52.191338  4400.0                64.838669
# 2020-06-01 00:01:00           52.479402  4400.0                64.838669
# 2020-06-01 00:02:00           52.804040  4400.0                64.838669
# 2020-06-01 00:03:00           53.156466  4400.0                64.838669
# 2020-06-01 00:04:00           53.727042  4400.0                64.977265
#
#                      sag power index_(t-2)  var_granulometry_10  \
# Timestamp
# 2020-06-01 00:00:00                  183.0             0.462283
# 2020-06-01 00:01:00                  183.0             0.481743
# 2020-06-01 00:02:00                  183.0             0.613046
# 2020-06-01 00:03:00                  183.0             0.842591
# 2020-06-01 00:04:00                  183.0             1.109349
#
#                      mean_solid percentage_5  min_charge cell_10  \
# Timestamp
# 2020-06-01 00:00:
# 2020-06-01 00:03:00                 820.0                 820.0
# 2020-06-01 00:04:00                 820.0                 820.0
#
#                      var_charge cell_5  granulometry  max_HH charge cell_3  \
# Timestamp
# 2020-06-01 00:00:00           1.771907     52.804040                 820.0
# 2020-06-01 00:01:00           3.410180     53.156466                 820.0
# 2020-06-01 00:02:00           5.192245     53.727042                 820.0
# 2020-06-01 00:03:00           2.843929     54.287458                 820.0
# 2020-06-01 00:04:00           1.566158     54.705388                 820.0
#
#                      charge cell_(t-2)  min_speed_3  var_HH charge cell_10  \
# Timestamp
# 2020-06-01 00:00:00         808.370729     8.870746                    0.0
# 2020-06-01 00:01:00         810.511489     8.873753                    0.0
# 2020-06-01 00:02:00         811.822555     8.871138                    0.0
# 2020-06-01 00:03:00         813.198992     8.868254                    0.0
# 2020-06-01 00:04:00         815.053266     8.868254                    0.0
#
#                      rms_LL charge cell_10  max_LL charge cell_10     speed  \
# Timestamp
# 2020-06-01 00:00:00                  740.0                  740.0  8.877953
# 2020-06-01 00:01:00                  740.0                  740.0  8.879825
# 2020-06-01 00:02:00                  740.0                  740.0  8.871138
# 2020-06-01 00:03:00                  740.0                  740.0  8.868254
# 2020-06-01 00:04:00                  740.0                  740.0  8.872953
#
#                      min_speed_10  var_charge cell_3  var_granulometry_3  \
# Timestamp
# 2020-06-01 00:00:00       8.86769           2.024094            0.062642
# 2020-06-01 00:01:00       8.86769           1.204016            0.076446
# 2020-06-01 00:02:00       8.86769           1.752268            0.144632
# 2020-06-01 00:03:00       8.86769           0.612137            0.213196
# 2020-06-01 00:04:00       8.86769           1.455609            0.160655
#
#                      mean_granulometry_10  mean_HH charge cell_5
# Timestamp
# 2020-06-01 00:00:00             51.649463                  820.0
# 2020-06-01 00:01:00             51.916847                  820.0
# 2020-06-01 00:02:00             52.204473                  820.0
# 2020-06-01 00:03:00             52.516270                  820.0
# 2020-06-01 00:04:00             52.839194                  820.0

# %%
# Ytest reg
Ytest=test["start high load cell"]
Xtest=test.drop(columns=["start high load cell"])

# %%
# Preprocesamiento de datos

preprocessing_transformer = ColumnTransformer(
    transformers=[
        ('MinMax', MinMaxScaler(),Xtrain.columns
        #features.columns.to_list()
        ),
    ])

pipe5 = Pipeline(
    [
        ("preprocesamiento", preprocessing_transformer), 
        #("Selection", SelectPercentile(f_classif, percentile=10)),
        #("PCA",PCA(n_components=150 )), #0.08
     ("clf", xgb.XGBClassifier(seed=1,  eval_metric='mlogloss',n_estimators=100,colsample_bytree=0.5,
     max_depth=15,min_child_weight=1,gamma=0.0001,learning_rate=0.001,#reg_lambda=0.8,reg_alpha=0.4
     ))
    ]
)

# %%
# Fit
pipe5.fit(Xtrain, Ytrain)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('MinMax', MinMaxScaler(),
#                                                   Index(['max_solid percentage_3', 'max_sag power index_5',
#        'max_sag power index_3', 'mean_charge cell_10', 'granulometry_(t-1)',
#        'granulometry_(t-3)', 'granulometry_(t-2)', 'HH TPH',
#        'min_solid percentage_10', 'sag power index_(t-2)',
#        ...
#        'min_speed_3', 'var_HH charge cell_10', 'rms...
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.001, max_delta_step=0,
#                                max_depth=15, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=8, num_parallel_tree=1, predictor='auto',
#                                random_state=1, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=1, seed=1, subsample=1,
#                                tree_method='exact', validate_parameters=1,
#                                verbosity=None))])

# %%
# Generación de predicciones
Ypred =pipe5.predict(Xtest)
print(classification_report( Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.85      0.92     44187
#          1.0       0.03      0.49      0.06       415
#
#     accuracy                           0.85     44602
#    macro avg       0.51      0.67      0.49     44602
# weighted avg       0.99      0.85      0.91     44602

# %%
# Matriz de confusión
matrix=confusion_matrix(Ytest,Ypred,normalize='true'
)
z=[matrix[0].round(2),matrix[1].round(2)]
fig = px.imshow(z, aspect="auto",labels=dict(x="Predicted label", y="True label"),x=["0", "1"],y=["0", "1"]
)

#axis_template = dict(showticklabels = False,ticks = '')
fig.update_layout(height=600,width=600,#title="Matriz de confusión normalizada",
# xaxis = axis_template,yaxis = axis_template,
)
fig.update_xaxes(side="top")
for i,r in enumerate(matrix):
    for k,c in enumerate(r):
        fig.add_annotation(x=k,y=i,
                           text='{}'.format(round(c,2)),
                           showarrow=False, bgcolor="white"
    )
                          
fig.show()

# %%
scores=pipe5.predict_proba(Xtest)[:, 1]
trues=list(Ytest) #Se usa de aqui en adelante

#Uso de "roc_curves()" para obtener "fpr","tpr":
fpr, tpr, thresholds = metrics.roc_curve(trues, scores, pos_label=1) #Pos_label: indica la etiqueta de la clase positiva

#Gráfico de curva ROC:
fig=px.line(x=fpr,y=tpr,labels={"y":"TPR","x":"FPR"})
fig.update_layout(height=500,width=700,title=f"Curva ROC: Área bajo la curva: {round(metrics.auc(fpr, tpr),2)}")
fig.show()

# %%
# Scaled Probabilities:
calibrated_clf = CalibratedClassifierCV(base_estimator=pipe5, method='sigmoid',cv='prefit')
calibrated_clf.fit(Xtrain,Ytrain)
calibrated_pred = calibrated_clf.predict_proba(Xtest)

# Threshold for probabilities that max precision:
train_prob = calibrated_clf.predict_proba(Xval)[:,1]
precision, recall, thresholds = precision_recall_curve(Yval, train_prob)
thresholds = np.append(thresholds,1)
#fig, ax = plt.subplots(figsize=(12,6))
#ax.plot(thresholds, precision, color='blue')
#ax.plot(thresholds, recall, color='red')

def f1_threshold(precision, recall):
    numer = 2*recall*precision
    denom = recall + precision
    f1_scores = np.divide(numer, denom, out=np.zeros_like(denom), where = (denom!=0))
    max_f1 = np.max(f1_scores)
    max_f1_thresh = thresholds[np.argmax(f1_scores)]
    print(str("Max F1: "+ str(max_f1)))
    print(str("Max Threshold: "+ str(max_f1_thresh)))
    return max_f1_thresh
    
threshold = f1_threshold(precision, recall)

Ypred_new=pd.Series(calibrated_pred[:,1]).apply(lambda x: 1 if x>threshold else 0)

print(classification_report( Ytest,Ypred_new))
# Out:
# Max F1: 0.07989800254993626
# Max Threshold: 0.05166948214173317
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.89      0.94     44187
#          1.0       0.03      0.35      0.05       415
#
#     accuracy                           0.89     44602
#    macro avg       0.51      0.62      0.50     44602
# weighted avg       0.98      0.89      0.93     44602

# %%
df_importance=pd.DataFrame({"tag":Xtrain.columns,"importance":pipe5["clf"].feature_importances_}).sort_values(by="importance",ascending=False).reset_index(drop=True)
df_importance
# Out:
#                        tag  importance
# 0     HH charge cell_(t-1)    0.055467
# 1     rms_LL charge cell_3    0.044142
# 2     min_HH charge cell_3    0.043880
# 3     HH charge cell_(t-2)    0.035271
# 4           HH charge cell    0.033743
# ..                     ...         ...
# 146           mean_speed_5    0.002063
# 147  max_sag power index_3    0.002049
# 148     granulometry_(t-1)    0.001786
# 149   max_HH charge cell_3    0.000000
# 150   LL charge cell_(t-3)    0.000000
#
# [151 rows x 2 columns]

# %%
pd.options.plotting.backend = "plotly"
fig=df_importance["importance"].plot(kind='hist')
fig.update_layout(height=500, width=1200,title="Feature importance XGBoost (Gain)",) 
fig.show()

# %%
df_importance[df_importance.tag=="random"]
# Out:
#         tag  importance
# 131  random    0.002561

# %%
# Plot
fig = go.Figure([go.Bar(x=df_importance["tag"], y=df_importance["importance"])])
fig.update_layout(height=500, width=1200,title="Feature importance XGBoost (Gain)",) 
fig.show()

# %%
# Función que filtra tags por alta correlación
def corrkill(dataframe, features, corr_cut=0.8):

    df = dataframe[features]
    df_corr=df.corr()
    dfcorr = pd.DataFrame(np.triu(df_corr), columns=df_corr.columns, index=df_corr.columns)
    dfcorr = dfcorr.stack().reset_index()
    dfcorr.columns = ['Feat1','Feat2','Val']
    dfcorr = dfcorr[~dfcorr['Val'].isin([0,1])]
    dfcorr = dfcorr[dfcorr['Val'].abs()>corr_cut]
    dfcorr["Val"]=dfcorr["Val"].abs()
    
    return list(dfcorr['Feat2']), dfcorr.sort_values(by="Val",ascending=False)

# %%
xgboost_fs=df_importance[:70].tag.to_list()
xgboost_fs
# Out:
# ['delta HH charge cell',
#  'var_charge cell_3',
#  'var_charge cell_10',
#  'granulometry',
#  'var_speed_3',
#  'var_granulometry_3',
#  'var_granulometry_5',
#  'var_granulometry_10',
#  'var_solid percentage_10',
#  'random',
#  'var_charge cell_5',
#  'var_solid percentage_5',
#  'var_solid percentage_3',
#  'var_speed_10',
#  'charge cell',
#  'HH TPH',
#  'var_speed_5',
#  'solid percentage_(t-4)',
#  'max_charge cell_10',
#  'granulometry_(t-5)',
#  'max_solid percentage_10',
#  'charge cell_(t-5)',
#  'solid percentage',
#  'min_solid percentage_10',
#  'speed',
#  'min_granulometry_10',
#  'min_charge cell_10',
#  'solid percentage_(t-5)',
#  'solid percentage_(t-3)',
#  'max_granulometry_10',
#  'speed_(t-2)',
#  'max_speed_10',
#  'min_sag power index_10',
#  'var_sag power index_3',
#  'speed_(t-1)',
#  'speed_(t-5)',
#  'var_sag power index_10',
#  'solid percentage_(t-1)',
#  'solid percentage_(t-2)',
#  'min_speed_10',
#  'max_sag power index_10',
#  'max_solid percentage_5',
#  'max_speed_3',
#  'charge cell_(t-3)',
#  'speed_(t-4)',
#  'charge cell_(t-2)',
#  'granulometry_(t-4)',
#  'mean_speed_3',
#  'max_charge cell_5',
#  'charge cell_(t-4)',
#  'granulometry_(t-3)',
#  'rms_charge cell_10',
#  'min_charge cell_5',
#  'min_speed_5',
#  'max_speed_5',
#  'Edad',
#  'mean_granulometry_10',
#  'charge cell_(t-1)',
#  'min_solid percentage_5',
#  'speed_(t-3)',
#  'max_solid percentage_3',
#  'min_granulometry_3',
#  'mean_charge cell_10',
#  'mean_speed_10',
#  'rms_speed_10',
#  'max_granulometry_3',
#  'mean_solid percentage_10',
#  'min_HH charge cell_10',
#  'sag power index_(t-5)',
#  'max_granulometry_5']

# %%
# Se obtienen tags altamente correlacionados y matriz que permite visualizar cuales son los par de tags altamente correlacionados
collinearity, table_cor=corrkill(Xtrain,xgboost_fs,corr_cut=0.9)

# %%
table_cor
# Out:
#                    Feat1                  Feat2       Val
# 3580  rms_charge cell_10    mean_charge cell_10  0.999994
# 1357  granulometry_(t-5)     granulometry_(t-4)  0.999284
# 267         granulometry     min_granulometry_3  0.999089
# 3229  granulometry_(t-4)   mean_granulometry_10  0.998982
# 1366  granulometry_(t-5)   mean_granulometry_10  0.998921
# ...                  ...                    ...       ...
# 3654   min_charge cell_5  min_HH charge cell_10  0.913376
# 1687               speed           max_speed_10  0.911508
# 1700               speed            speed_(t-4)  0.911165
# 2733        min_speed_10            max_speed_3  0.910731
# 1860  min_charge cell_10  min_HH charge cell_10  0.908081
#
# [279 rows x 3 columns]

# %%
tag_select = [i for i in xgboost_fs if i not in collinearity]
len(tag_select)
# Out:
# 23

# %%
tag_select
# Out:
# ['delta HH charge cell',
#  'var_charge cell_3',
#  'var_charge cell_10',
#  'granulometry',
#  'var_speed_3',
#  'var_granulometry_3',
#  'var_granulometry_5',
#  'var_granulometry_10',
#  'var_solid percentage_10',
#  'random',
#  'var_charge cell_5',
#  'var_solid percentage_5',
#  'var_solid percentage_3',
#  'var_speed_10',
#  'charge cell',
#  'HH TPH',
#  'var_speed_5',
#  'solid percentage_(t-4)',
#  'speed',
#  'min_sag power index_10',
#  'var_sag power index_3',
#  'var_sag power index_10',
#  'Edad']

# %%
train_data = lgb.Dataset(Xtrain[tag_select], label=Ytrain, )

# %%
validation_data = lgb.Dataset(Xval[tag_select], label=Yval, )

# %%
num_round = 10
bst = lgb.train({},train_set=train_data, feature_name=tag_select,valid_sets=[validation_data])
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038788 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5485
# [LightGBM] [Info] Number of data points in the train set: 326476, number of used features: 23
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.500000

# %%
Ypred = [1 if valor > 0.5 else 0 for valor in bst.predict(Xtest[tag_select], num_iteration=bst.best_iteration)]

print(classification_report( Ytest,Ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.75      0.85     44187
#          1.0       0.03      0.73      0.05       415
#
#     accuracy                           0.75     44602
#    macro avg       0.51      0.74      0.45     44602
# weighted avg       0.99      0.75      0.85     44602

# %%
explainerModel = shap.TreeExplainer(bst)
explainerModel_X = explainerModel(Xtrain[tag_select])
shap_values_Model = explainerModel.shap_values(Xtrain[tag_select])

# %%
shap.summary_plot(shap_values_Model,Xtrain[tag_select], plot_size=[15,10])

# %%
shap.plots.bar(explainerModel_X, max_display=20,)
plt.figure(figsize=(12, 12))
plt.show()
