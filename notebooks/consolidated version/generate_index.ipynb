# %%
import pandas as pd

# %%
# read df full csv
df=pd.read_csv('../../data/consolidated data/consolidation_15December2022.csv', parse_dates=['Timestamp'], index_col='Timestamp')
df.sort_index(inplace=True)
df.shape
# Out:
# (2475480, 37)

# %%
df_index=pd.DataFrame()
df_index
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["2022"]
# Out:
# C:\Users\JOSELU~1.CAD\AppData\Local\Temp/ipykernel_8080/112099719.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2022"]
#                      CF:EXPERTO.HAB_EXP.CO_1.FOX  \
# Timestamp
# 2022-01-01 00:00:00                          1.0
# 2022-01-01 00:01:00                          1.0
# 2022-01-01 00:02:00                          1.0
# 2022-01-01 00:03:00                          1.0
# 2022-01-01 00:04:00                          1.0
# ...                                          ...
# 2022-09-16 01:55:00                          NaN
# 2022-09-16 01:56:00                          NaN
# 2022-09-16 01:57:00                          NaN
# 2022-09-16 01:58:00                          NaN
# 2022-09-16 01:59:00                          NaN
#
#                      Limitado por Límite Alto de Tonelaje  \
# ...

# %%
df_index
# Out:
#                      index
# 0      2022-01-01 00:00:00
# 1      2022-01-01 00:01:00
# 2      2022-01-01 00:02:00
# 3      2022-01-01 00:03:00
# 4      2022-01-01 00:04:00
# ...                    ...
# 371635 2022-09-16 01:55:00
# 371636 2022-09-16 01:56:00
# 371637 2022-09-16 01:57:00
# 371638 2022-09-16 01:58:00
# 371639 2022-09-16 01:59:00
#
# [371640 rows x 1 columns]

# %%
anio="2022"
df_index=pd.DataFrame()
df_index["index"]=df[anio].index
df_index.to_csv(f'../../data/df_index_{anio}.csv')
# Out:
# C:\Users\JOSELU~1.CAD\AppData\Local\Temp/ipykernel_8080/3364238326.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_index["index"]=df[anio].index
